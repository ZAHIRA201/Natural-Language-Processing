# %% [markdown]
# # TextGeneration

# %% [markdown]
# ## Prétraitement des Tweets

# %%
import re
import string
from typing import List, Tuple
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Téléchargement des ressources NLTK 
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## preprocess_tweet(tweet: str) -> str

# %% [markdown]
# Cette fonction prend en entrée un tweet et le prétraite en supprimant les emojis, les mentions d'utilisateur, les hashtags, les liens URL, les chiffres et la ponctuation.

# %%
def preprocess_tweet(tweet: str) -> str:
    """
    Prétraitement d'un tweet en supprimant les emojis, les mentions d'utilisateur,
    les hashtags, les liens URL, les chiffres et la ponctuation.
    """
    # Supprimer les emojis
    tweet = re.sub(r'[^\w\s,]', '', tweet)
    
    # Supprimer les mentions d'utilisateur (@username)
    tweet = re.sub(r'@[A-Za-z0-9_]+', '', tweet)
    
    # Supprimer les hashtags (#hashtag)
    tweet = re.sub(r'#([^\s]+)', '', tweet)
    
    # Supprimer les liens URL (http://...)
    tweet = re.sub(r'http\S+', '', tweet)
    
    # Supprimer les chiffres
    tweet = re.sub(r'\d+', '', tweet)
    
    # Supprimer la ponctuation
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    
    return tweet

# %% [markdown]
# ## tokenize_tweet(tweet: str) -> list

# %% [markdown]
# Cette fonction tokenise un tweet en utilisant TweetTokenizer de NLTK.

# %%
def tokenize_tweet(tweet: str) -> list:
    """
    Tokenisation d'un tweet en utilisant TweetTokenizer de NLTK.
    """
    tokenizer = TweetTokenizer()
    tokens = tokenizer.tokenize(tweet)
    return tokens

# %% [markdown]
# ## remove_stopwords(tokens: list) -> list

# %% [markdown]
# Cette fonction supprime les mots vides de la liste de tokens en anglais.

# %%
def remove_stopwords(tokens: list) -> list:
    """
    Suppression des mots vides de la liste de tokens.
    """
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [token for token in tokens if token.lower() not in stop_words]
    return filtered_tokens

# %% [markdown]
# ## lemmatize_tokens(tokens: list) -> list

# %% [markdown]
# Cette fonction lemmatise les tokens en utilisant WordNetLemmatizer de NLTK.

# %%
def lemmatize_tokens(tokens: list) -> list:
    """
    Lemmatisation des tokens en utilisant WordNetLemmatizer de NLTK.
    """
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return lemmatized_tokens

# %% [markdown]
# ## preprocess_tweets_from_file(file_path: str) -> list

# %% [markdown]
# Cette fonction prétraite les tweets à partir d'un fichier.

# %%
def preprocess_tweets_from_file(file_path: str) -> list:
    """
    Prétraitement des tweets à partir d'un fichier.
    """
    preprocessed_tweets = []
    
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            tweet = line.strip()
            preprocessed_tweet = preprocess_tweet(tweet)
            tokens = tokenize_tweet(preprocessed_tweet)
            filtered_tokens = remove_stopwords(tokens)
            lemmatized_tokens = lemmatize_tokens(filtered_tokens)
            preprocessed_tweets.append(lemmatized_tokens)
    
    return preprocessed_tweets

# %%
def process_data(data: str) -> Tuple[List[str], List[List[str]]]:
    """
    Tokenize les données en phrases et en mots, en utilisant le prétraitement des tweets.

    Paramètres :
        data (str) : Les données d'entrée sous forme de chaîne de caractères.

    Retourne :
        Tuple[List[str], List[List[str]]] : Un tuple contenant la liste des phrases et la liste des phrases tokenisées.
    """
    def tokenizer_phrase(phrase: str) -> List[str]:
        return preprocess_tweet(phrase).split()

    phrases = data.split('\n')
    phrases = [phrase.strip() for phrase in phrases if phrase.strip()]
    phrases_tokenisees = [tokenizer_phrase(p) for p in phrases]
    
    return phrases, phrases_tokenisees

# %%
file_path = "C:\\Users\\user\\Downloads\\23032024125908292688468987\\PA_files\\big_data_chunk_1.txt"


with open(file_path, 'r', encoding='utf-8') as file:
    data = file.read()
phrases, phrases_tokenisees = process_data(data)
print("\nPhrases tokenisées :") : 

for tokens in phrases_tokenisees:
    print(tokens)
# Out:
# Phrases tokenisées :
# ['How', 'are', 'you', 'Btw', 'thanks', 'for', 'the', 'RT', 'You', 'gonna', 'be', 'in', 'DC', 'anytime', 'soon', 'Love', 'to', 'see', 'you', 'Been', 'way', 'way', 'too', 'long']
# ['When', 'you', 'meet', 'someone', 'special', 'youll', 'know', 'Your', 'heart', 'will', 'beat', 'more', 'rapidly', 'and', 'youll', 'smile', 'for', 'no', 'reason']
# ['theyve', 'decided', 'its', 'more', 'fun', 'if', 'I', 'dont']
# ['So', 'Tired', 'D', 'Played', 'Lazer', 'Tag', 'Ran', 'A', 'LOT', 'D', 'Ughh', 'Going', 'To', 'Sleep', 'Like', 'In', 'Minutes']
# ['Words', 'from', 'a', 'complete', 'stranger', 'Made', 'my', 'birthday', 'even', 'better']
# ['First', 'Cubs', 'game', 'ever', 'Wrigley', 'field', 'is', 'gorgeous', 'This', 'is', 'perfect', 'Go', 'Cubs', 'Go']
# ['i', 'no', 'i', 'get', 'another', 'day', 'off', 'from', 'skool', 'due', 'to', 'the', 'wonderful', 'snow', 'and', 'THIS', 'wakes', 'me', 'updamn', 'thing']
# ['Im', 'coo', 'Jus', 'at', 'work', 'hella', 'tired', 'r', 'u', 'ever', 'in', 'cali']
# ['The', 'new', 'sundrop', 'commercial', 'hehe', 'love', 'at', 'first', 'sight']
# ['we', 'need', 'to', 'reconnect', 'THIS', 'WEEK']
# ['I', 'always', 'wonder', 'how', 'the', 'guys', 'on', 'the', 'auctions', 'shows', 'learned', 'to', 'talk', 'so', 'fast', 'all', 'I', 'hear', 'is', 'djsosnekspqnslanskam']
# ['Dammnnnnn', 'what', 'a', 'catch']
# ['such', 'a', 'great', 'picture', 'The', 'green', 'shirt', 'totally', 'brings', 'out', 'your', 'eyes']
# ['Desk', 'put', 'together', 'room', 'all', 'set', 'up', 'Oh', 'boy', 'oh', 'boy']
# ['Im', 'doing', 'it']
# ['Beauty', 'Brainstorming', 'in', 'the', 'Alchemy', 'office', 'with', 'and', 'Sally', 'Walker']
# ['Looking', 'for', 'a', 'new', 'band', 'to', 'blog', 'for', 'the', 'month', 'anyone', 'interested']
# ['Packing', 'for', 'a', 'quick', 'move', 'down', 'the', 'street', 'If', 'only', 'I', 'had', 'some', 'movers']
# ['ford', 'focus', 'hatchback']
# ['RT', 'According', 'to', 'the', 'National', 'Retail', 'Federation', 'BILLION', 'was', 'spent', 'on', 'MothersDay', 'last', 'year']
# ['The', 'tragedy', 'of', 'life', 'is', 'not', 'that', 'it', 'ends', 'so', 'soon', 'but', 'that', 'we', 'wait', 'so', 'long', 'to', 'begin', 'it', 'WM', 'Lewis']
# ['More', 'skating', 'Come', 'by', 'the', 'check', 'out', 'a', 'movie', 'eat', 'a', 'great', 'dinner', 'and', 'top', 'it', 'off', 'with', 'great', 'times', 'at', 'the', 'ice', 'rink']
# ['watch', 'your', 'mailbox']
# ['Tommorows', 'the', 'day']
# ['Good', 'questions', 'RT', 'Your', 'brand', 'will', 'be', 'judged', 'based', 'on', 'its', 'website', 'Is', 'your', 'website', 'a', 'good', 'brand', 'ambassador']
# ['Dont', 'care', 'what', 'others', 'think', 'of', 'you', 'and', 'you', 'will', 'save', 'yourself', 'a', 'lot', 'of', 'mental', 'energy', 'that', 'instead', 'can', 'be', 'used', 'to', 'push', 'you', 'towards', 'success']
# ['This', 'Ron', 'Artest', 'interview', 'is', 'it', 'possible', 'to', 'die', 'from', 'laughter']
# ['Linda', 'Just', 'looked', 'at', 'my', 'sched', 'I', 'have', 'to', 'hustle', 'back', 'to', 'Chula', 'for', 'PM', 'meetings', 'so', 'no', 'time', 'lunch', 'Do', 'u', 'meet', 'every', 'Fri']
# ['Bum', 'Squad', 'lets', 'get', 'it', 'RT', 'Shout', 'that', 'ninja', 'out', 'for', 'winning']
# ['I', 'love', 'you', 'and', 'Im', 'so', 'proud', 'of', 'you', 'From', 'sitting', 'on', 'those', 'stairs', 'on', 'The', 'X', 'Factor', 'to', 'now', 'You', 'boys', 'are', 'my', 'inspiration', 'xx']
# ['Maybe', 'some', 'other', 'time', 'I', 'cant', 'slow', 'down', 'right', 'across', 'that', 'state', 'line', 'right', 'about', 'now']
# ['Exhaust', 'leak', 'arrrgh']
# ['i', 'Love', 'Reading', 'your', 'magazine', 'it', 'always', 'cheers', 'me', 'up']
# ['Tables', 'are', 'all', 'sold', 'out', 'for', 'the', 'Mystique', 'Masquerade', 'Ball']
# ['Make', 'one', 'up', 'It', 'might', 'help', 'you', 'feel', 'better', 'Alternative', 'just', 'scream', 'nonsense', 'at', 'the', 'dumb', 'machine']
# ['ya', 'ik', 'and', 'i', 'never', 'asked', 'him', 'to', 'follow', 'me', 'i', 'only', 'mentioned', 'him', 'once', 'in', 'one', 'of', 'my', 'tweets', 'i', 'didnt', 'do', 'anything', 'else']
# ['I', 'will']
# ['Great', 'talking', 'to', 'you', 'guys', 'tonight', 'Looking', 'forward', 'to', 'your', 'piece', 'next', 'week', 'Jon']
# ['Small', 'market', 'baseball', 'You', 'knowfor', 'the']
# ['Sing', 'it']
# ['it', 'comes', 'on', 'tonight', 'not', 'tomorrow']
# ['maybe', 'just', 'seems', 'they', 'thought', 'up', 'that', 'idea', 'over', 'sunday', 'brunch', 'and', 'thought', 'it', 'was', 'swell']
# ['Thanks', 'for', 'the', 'FF', 'Awfully', 'good', 'company', 'to', 'be', 'in']
# ['The', 'longer', 'we', 'live', 'the', 'more', 'we', 'find', 'we', 'are', 'like', 'other', 'persons', 'Oliver', 'Wendell', 'Holmes']
# ['made', 'my', 'list', 'for', 'top', 'women']
# ['nice', 'I', 'watched', 'the', 'whole', 'series', 'LOVED', 'Julia', 'and', 'her', 'mom', 'Erica', 'was', 'such', 'a', 'badass']
# ['GOP', 'line', 'on', 'Obama', 'gay', 'marriage', 'stance', 'seems', 'to', 'be', 'that', 'he', 'flipflopped', 'Really', 'want', 'to', 'use', 'that', 'with', 'Romney', 'as', 'your', 'presidential', 'candidate']
# ['I', 'know', 'I', 'know', 'Then', 'you', 'kick', 'yourself', 'when', 'the', 'fight', 'goes', 'lopsided', 'But', 'if', 'the', 'upset', 'DOES', 'happen', 'wow', 'Nothing', 'like', 'it']
# ['No', 'stress', 'balls', 'or', 'keg', 'and', 'different', 'crew', 'but', 'these', 'guys', 'know', 'how', 'to', 'party']
# ['William', 'Davis', 'attorney', 'says', 'client', 'will', 'plead', 'insanity', 'He', 'faces', 'firstdegree', 'murder', 'charge', 'in', 'womans', 'death']
# ['OccupyMadison', 'GA', 'I', 'always', 'considered', 'myself', 'a', 'liberal', 'until', 'I', 'saw', 'the', 'liberal', 'machine', 'in', 'action', 'It', 'was', 'ugly']
# ['Weird', 'thought', 'we', 'got', 'to', 'witness', 'the', 'change', 'of', 'a', 'millenia', 'the', 'next', 'change', 'is', 'generations', 'awayimagine', 'what', 'the', 'differences', 'will', 'be']
# ['got', 'a', 'good', 'one']
# ['love', 'chris', 'brown']
# ['Wit', 'them', 'sexy', 'ass', 'lips']
# ['its', 'sounds', 'good']
# ['How', 'unfortunate', 'that', 'those', 'days', 'when', 'every', 'status', 'update', 'was', 'a', 'song', 'lyrics', 'were', 'also', 'the', 'days', 'when', 'I', 'first', 'discovered', 'New', 'Wave']
# ['I', 'had', 'a', 'bomb', 'ass', 'day', 'Chillin', 'with', 'friends']
# ['Working', 'on', 'music', 'for', 'Holiday', 'show', 'on', 'the', 'in', 'Santa', 'Barbara', 'OPEN', 'BAR', 'Me', 'Tim', 'from', 'Palin', 'White', 'Ts', 'and', 'JR', 'Richards', 'from', 'Dishwalla']
# ['Hey', 'Nate', 'Thanks', 'for', 'dropping', 'by', 'yesterday', 'How', 'was', 'your', 'meal']
# ['FF', 'literary', 'lights', 'who', 'brightened', 'my', 'week']
# ['Time', 'to', 'shape', 'up', 'Water', 'pavement', 'weights', 'and', 'zija', 'are', 'going', 'to', 'be', 'my', 'friends', 'wedding', 'just', 'months', 'away']
# ['Report', 'the', 'many', 'things', 'that', 'are', 'positive', 'about', 'the', 'University', 'of', 'Arkansas', 'athletics', 'program']
# ['Athletescelebrities', 'should', 'have', 'a', 'tool', 'to', 'charge', 'per', 'RT', 'request', 'to', 'support', 'foundationscharities', 'fans', 'get', 'involved']
# ['Enjoy', 'Stay', 'cool']
# ['yo', 'chick', 'she', 'so', 'thirst', 'aye', 'I', 'really', 'dont', 'know', 'what', 'else', 'theyre', 'saying', 'tho', 'except', 'that', 'lol']
# ['talks', 'in', 'third', 'person']
# ['many', 'things', 'can', 'happen', 'Only', 'YOU', 'can', 'control', 'your', 'reaction', 'to', 'it', 'Practice', 'this', 'good']
# ['You', 'will', 'allow', 'me', 'to', 'continue', 'to', 'do', 'what', 'I', 'love', 'Big', 'Shows', 'wife']
# ['haha', 'very', 'cute', 'Have', 'u', 'heard', 'from', 'julie', 'Whos', 'that', 'on', 'her', 'fb', 'Im', 'tryin', 'not', 'to', 'laugh']
# ['and', 'somedays', 'youre', 'the', 'windshield', 'wiper']
# ['Im', 'taking', 'Adam']
# ['lets', 'do', 'this']
# ['Not', 'much', 'Ben', 'hows', 'you']
# ['Sarah', 'trying', 'to', 'explain', 'to', 'my', 'teacher', 'YOLO', 'lmfao']
# ['Inspiring', 'RT', 'Great', 'minds', 'must', 'be', 'ready', 'not', 'only', 'to', 'take', 'opportunities', 'but', 'to', 'make', 'them', 'Colton']
# ['med', 'schoolwow', 'I', 'could', 'never', 'do', 'that', 'Am', 'too', 'OCD', 'to', 'be', 'around', 'blood', 'and', 'sick', 'people', 'for', 'long', 'periods', 'of', 'time']
# ['Sleeping', 'Not', 'likely', 'RT', 'Sleeping', 'to']
# ['Time', 'for', 'lunch']
# ['Not', 'being', 'dependent', 'on', 'anyone', 'for', 'your', 'happiness']
# ['This', 'humidity', 'is', 'not', 'sitting', 'well', 'with', 'me', 'at', 'all', 'NeedACInSchool', 'D']
# ['Do', 'u', 'know', 'whats', 'creepily', 'I', 'Hate', 'Cheesecake', 'Its', 'Cake', 'with', 'Cheese', 'in', 'front', 'of', 'it']
# ['thanks', 'Got', 'it', 'at', 'walmart']
# ['Still', 'havent', 'seen', 'Super', 'Every', 'th', 'checkin', 'wins', 'a', 'free', 'movie', 'ticket', 'checkins', 'so', 'far']
# ['RT', 'Congratulations', 'to', 'the', 'for', 'advancing', 'in', 'the', 'stanleycup', 'Playoffs', 'They', 'defeated', 'the', 'Sens', 'in', 'a', 'series']
# ['Hey', 'hey', 'hey', 'can', 'i', 'meet', 'chaaaa']
# ['Ghost', 'Hunters', 'makes', 'me', 'cry']
# ['Whos', 'going', 'to', 'the', 'OVW', 'show', 'tomorrow', 'your', 'team', 'dominoski', 'will', 'be', 'in', 'the', 'house', 'First', 'brew', 'after', 'the', 'show', 'is', 'on', 'me']
# ['just', 'waking', 'up', 'but', 'therave', 'last', 'night', 'though']
# ['at', 'six', 'flags']
# ['Thanks', 'Tom']
# ['Theyre', 'not', 'applauding', 'because', 'you', 'dont', 'have', 'a', 'button']
# ['im', 'not', 'mad', 'it', 'just', 'sucks', 'that', 'i', 'cant', 'show', 'you', 'off', 'THIS']
# ['Im', 'at', 'little', 'league', 'majors', 'try', 'outs', 'in']
# ['Where', 'my', 'meatballs', 'at', 'and', 'Naomi']
# ['Doing', 'some', 'cufon', 'testing', 'and', 'implementation', 'in', 'wordpress', 'What', 'the', 'FOUC', 'dyall', 'think', 'of', 'cufon']
# ['lo', 'mejor', 'it', 'was', 'cool', 'experiencing', 'work', 'through', 'the', 'eyes', 'of', 'an', 'excited', 'teen']
# ['Me', 'the', 'only', 'b', 'word', 'u', 'should', 'call', 'a', 'girl', 'is', 'beautful', 'Colin', 'or', 'a', 'butterfly']
# ['I', 'just', 'think', 'that', 'the', 'zooming', 'is', 'overused', 'It', 'needs', 'to', 'be', 'done', 'tastefully', 'And', 'its', 'not', 'the', 'point']
# ['If', 'you', 'have', 'Firefox', 'or', 'Google', 'Chrome', 'type', 'in', 'let', 'it', 'snow', 'into', 'google', 'today']
# ['hahahahhahah', 'u', 'just', 'made', 'my', 'day', 'D']
# ['I', 'can', 'hear', 'High', 'and', 'Dry', 'through', 'the', 'walls', 'Amazing']
# ['RT', 'IMPORTANT', 'Our', 'new', 'hashtag', 'is', 'SNTCK', 'please', 'tweet', 'your', 'specialneeds', 'resources', 'and', 'writings', 'with', 'us', 'to', 'share']
# ['Proud', 'to', 'have', 'voted', 'twice', 'for', 'the', 'SAGAFTRA', 'merger', 'Have', 'you', 'voted', 'yet']
# ['this', 'conference', 'is', 'rockin']
# ['Pretty', 'sure', 'that', 'was', 'a', 'broken', 'leg']
# ['Keith', 'was', 'also', 'good', 'a', 'smoking', 'in', 'the', 'dugout', 'and', 'being', 'a', 'class', 'a', 'jerk', 'I', 'grew', 'up', 'a', 'Mets', 'fansorry', 'to', 'admit']
# ['Shes', 'calling', 'you', 'back', 'is', 'having', 'a', 'moment']
# ['Reward', 'yourself', 'for', 'just', 'getting', 'up', 'in', 'the', 'morning', 'Its', 'a', 'wonderful', 'accomplishment']
# ['Big', 'ups', 'to', 'for', 'leaving', 'voicemails', 'that', 'Google', 'can', 'accurately', 'transcribe']
# ['GET', 'BETTER']
# ['Everyone', 'say', 'a', 'prayer', 'for', 'my', 'brother', 'who', 'is', 'at', 'Wrigley', 'field', 'with', 'his', 'wife', 'and', 'kids', 'She', 'and', 'her', 'daughters', 'are', 'in', 'Cardinals', 'jerseys']
# ['Why', 'you', 'actin', 'like', 'that', 'towards', 'me', 'now']
# ['Have', 'a', 'great', 'eveningafternoonwhatever', 'it', 'is', 'where', 'you', 'are', 'folks']
# ['experience', 'of', 'a', 'life', 'time']
# ['Hey', 'how', 'did', 'you', 'like', 'Dogtooth', 'I', 'watched', 'like', 'six', 'months', 'ago', 'but', 'dont', 'know', 'anyone', 'else', 'who', 'saw', 'it']
# ['The', 'average', 'gossip', 'and', 'complain', 'The', 'exceptional', 'create', 'and', 'inspire', 'leadership', 'RT']
# ['OneThingYouShouldntDo', 'Spam', 'someone', 'to', 'DEATH', 'its', 'like', 'stalking', 'them', 'Like', 'really']
# ['me', 'too']
# ['Buffalo', 'we', 'do', 'appreciate', 'you', 'following', 'Poised', 'Creation', 'on', 'Twitter']
# ['I', 'promise', 'you', 'can', 'go', 'ten', 'minutes', 'without', 'hanging', 'on', 'his', 'arm']
# ['Snap', 'backs', 'and', 'tattoos']
# ['Fallout', 'from', 'the', 'original', 'actually']
# ['who', 'is', 'your', 'favorite', 'tv', 'mom']
# ['Hey', 'Giants', 'fans', 'How', 'ya', 'feeling', 'tonight', 'Boy', 'do', 'you', 'look', 'dumb', 'in', 'that', 'stupid', 'panda', 'hat']
# ['out', 'of', 'twitter', 'jail', 'i', 'see']
# ['IT', 'PUTS', 'THE', 'WOO', 'IN', 'MY', 'WOO']
# ['People', 'can', 'keep', 'talkingThy', 'can', 'say', 'what', 'thy', 'likeI', 'dont', 'worry', 'cause', 'everythings', 'goin', 'be', 'alrightNo', 'one', 'get', 'n', 'way', 'I', 'feeling', 'JESUS']
# ['Drawn', 'Dead', 'will', 'be', 'at', 'the', 'Wynn', 'today', 'giving', 'out', 'free', 'shirts']
# ['the', 'fact', 'that', 'i', 'added', 'an', 'extra', 'd', 'on', 'the', 'end', 'of', 'just', 'amplifies', 'its', 'greatness', 'that', 'much', 'more', 'Oy', 'vey']
# ['Hmm', 'I', 'got', 'hackeddo', 'not', 'open', 'that', 'link', 'in', 'the', 'DM', 'that', 'was', 'sent', 'from', 'my', 'account', 'Sorry', 'Yikes']
# ['dont', 'break', 'my', 'butt']
# ['youre', 'welcome']
# ['O', 'intrigued', 'by', 'Were', 'in', 'negotiations', 'for', 'building', 'our', 'new', 'website']
# ['So', 'what', 'do', 'you', 'do', 'in', 'OKC']
# ['the', 'fact', 'that', 'lives', 'on', 'an', 'island', 'makes', 'me', 'wanna', 'shoot', 'myself', 'because', 'i', 'need', 'to', 'see', 'her', 'at', 'least', 'every', 'other', 'day', 'to', 'feel', 'sane']
# ['Players', 'were', 'Tebowing', 'before', 'Sat', 'NFL', 'Astroturf', 'Collegiate', 'Bowl', 'Praying', 'in', 'the', 'end', 'zone', 'before', 'the', 'game', 'and', 'Tebowing', 'a', 'great', 'stite']
# ['Yes', 'they', 'can']
# ['Hahahahaha', 'I', 'love', 'it', 'Thanks', 'for', 'the', 'quick', 'birthday', 'lesson']
# ['Im', 'Almost', 'Up', 'To', 'Youu']
# ['Tonight', 'should', 'be', 'fun']
# ['I', 'spy', 'at', 'Zeitgeist', 'Coffee']
# ['Thanks', 'for', 'the', 'retweet']
# ['be', 'quiet', 'poo', 'balls', 'Im', 'writing', 'this', 'on', 'my', 'wall']
# ['Sarkozy', 'More', 'like', 'Sarkohnohedidntzy', 'am', 'I', 'right']
# ['going', 'through', 'RNRCHI', 'bag', 'wondering', 'if', 'people', 'actually', 'pay', 'to', 'do', 'the', 'ready', 'to', 'run', 'mile', 'training', 'run']
# ['Thats', 'game', 'we', 'lost', 'I', 'cant', 'hate', 'on', 'the', 'Heat', 'Good', 'Game']
# ['The', 'Marlins', 'wish', 'they', 'had', 'in', 'attendance', 'tonight']
# ['for', 'Nelson']
# ['Tweetin', 'while', 'I', 'walk', 'Check', 'my', 'walkin', 'soundtrack']
# ['are', 'you', 'visiting', 'again', 'cause', 'that', 'would', 'be', 'awesome']
# ['no', 'its', 'the', 'interview', 'he', 'told', 'us', 'about', 'in', 'class', 'member']
# ['Who', 'has', 'the', 'bigger', 'stick']
# ['These', 'late', 'night', 'walks', 'are', 'still', 'religion', 'to', 'me', 'Thank', 'goodness', 'for', 'these']
# ['Is', 'that', 'a', 'rhetorical', 'question']
# ['I', 'want', 'a', 'new', 'phone', 'case', 'Preferably', 'a', 'sparkly', 'one']
# ['Everybody', 'in', 'the', 'class', 'is', 'laughing', 'at', 'this', 'part', 'and', 'I', 'had', 'no', 'idea', 'what', 'was', 'said', 'p']
# ['Bestfriend', 'just', 'got', 'hit', 'on', 'my', 'a', 'something', 'year', 'old']
# ['thanks', 'for', 'the', 'follow', 'Your', 'Gorgeous', 'btw']
# ['oh', 'boo', 'and', 'here', 'I', 'was', 'promoting', 'what', 'I', 'thought', 'it', 'would', 'be', 'to', 'a', 'friend', 'yesterday', 'Let', 'me', 'know', 'if', 'the', 'cobbler', 'needs', 'help']
# ['Collaboration', 'addresses', 'complex', 'problems', 'more', 'effectively', 'because', 'there', 'are', 'more', 'perspectives', 'in', 'the', 'roomGary', 'Mangiofico']
# ['cinco', 'de', 'mayo', 'fiesta', 'at', 'la', 'carreta', 'is', 'packed']
# ['Dallas', 'slapped', 'me', 'on', 'my', 'red', 'as', 'cherries', 'sunburn', 'and', 'im', 'still', 'crying', 'aftr', 'mins', 'i', 'hate', 'him']
# ['is', 'that', 'kind', 'of', 'place', 'Like', 'in', 'DC', 'Ladybugs', 'lurv', 'it']
# ['Well', 'Done']
# ['I', 'was', 'born', 'weeks', 'early', 'Haha']
# ['cant', 'wait', 'till']
# ['you', 'are', 'gorgeous', 'em']
# ['Thats', 'what', 'I', 'thought', 'just', 'wanted', 'to', 'check', 'before', 'I', 'rework', 'it']
# ['adele', 'gets', 'off', 'a', 'standing', 'ovation', 'right', 'away']
# ['Keep', 'moving', 'and', 'get', 'out', 'of', 'the', 'way']
# ['yeah', 'l', 'could', 'be', 'the', 'bigger', 'person', 'or', 'you', 'could', 'just', 'shut', 'the', 'fuck', 'up']
# ['anything', 'intriguing', 'going', 'over', 'there', 'Any', 'clues', 'on', 'who', 'the', 'browns', 'draft', 'next']
# ['Being', 'chauffeured', 'in', 'a', 'brand', 'new', 'Range', 'Rover', 'w', 'and', 'Happy', 'Derby', 'day']
# ['I', 'lost', 'pounds', 'sweating', 'in', 'sparring', 'class', 'today']
# ['Let', 'peace', 'find', 'a', 'toe', 'hold', 'in', 'this', 'tumultuous', 'world']
# ['Reminder', 'we', 'play', 'in', 'Dallas', 'tonight', 'at', 'the', 'den', 'p', 'start', 'See', 'yall', 'there']
# ['me', 'too']
# ['And', 'thank', 'everyone', 'of', 'you', 'who', 'has', 'taken', 'the', 'time', 'out', 'of', 'your', 'day', 'to', 'listen', 'to', 'us', 'your', 'all', 'amazing', 'much', 'love', 'hp']
# ['in', 'MD', 'MIAAA', 'Boys', 'Lax', 'action', 'St', 'Marys', 'Annapolis', 'goes', 'into', 'LoyolaBlakefields', 'house', 'and', 'leaves', 'with', 'a', 'victory']
# ['FridayTheth', 'is', 'the', 'best', 'movie', 'everand', 'todays', 'date']
# ['The', 'poor', 'needs', 'relief', 'and', 'they', 'need', 'it', 'now', 'Somebody', 'help']
# ['Okay', 'so', 'apparently', 'its', 'not', 'new', 'Sorry', 'for', 'having', 'a', 'life', 'and', 'not', 'listening', 'to', 'music', 'all', 'day', 'long']
# ['Heard', 'PM', 'was', 'in', 'Broncos', 'training', 'facility', 'all', 'day', 'even', 'had', 'a', 'Hour']
# ['that', 'is', 'hilarious', 'We', 'need', 'to', 'do', 'what', 'we', 'can', 'to', 'feel', 'young']
# ['I', 'had', 'the', 'weirdest', 'dreams', 'last', 'night']
# ['scrapbook', 'class', 'Next', 'up', 'hinged', 'reattachment', 'of', 'enclosures', 'w', 'wheat', 'paste', 'and', 'Japanese', 'tissue', 'Its', 'like', 'Im', 'at', 'nerd', 'camp']
# ['If', 'your', 'girlfriends', 'parents', 'pay', 'her', 'cell', 'phone', 'bill']
# ['thanks', 'Ill', 'definitely', 'be', 'using', 'some', 'Edmundson']
# ['This', 'Little', 'Girl', 'by', 'Cady', 'Groves', 'I', 'it', 'Look', 'it', 'up']
# ['YourKoz', 'GamesFind', 'out', 'who', 'this', 'isShe', 'concentrates', 'on', 'the', 'calibre', 'and', 'quality', 'of', 'education', 'for', 'Jordanian', 'children', 'global', 'education']
# ['can', 'u', 'please', 'RT', 'or', 'follow', 'im', 'one', 'of', 'your', 'biggest', 'fans']
# ['The', 'tea', 'party', 'movement', 'filled', 'the', 'gap', 'in', 'republican', 'party', 'on', 'intolerance', 'for', 'overspending']
# ['Flores', 'says', 'vocational', 'training', 'is', 'his', 'backyard', 'Admiration', 'for', 'police', 'nurses']
# ['In', 'Krav', 'Maga', 'there', 'are', 'no', 'rules', 'no', 'restrictions']
# ['Thank', 'you', 'Im', 'proud', 'of', 'us', 'all']
# ['I', 'love', 'you', 'brianana']
# ['As', 'for', 'me', 'and', 'my', 'house', 'we', 'will', 'serve', 'the', 'Lord', 'And', 'we', 'will', 'embrace', 'our', 'LGBT', 'brothers', 'and', 'sisters']
# ['im', 'following', 'u', 'so', 'u', 'cant', 'welch', 'lol']
# ['Plan', 'on', 'being', 'a', 'DJ']
# ['I', 'actually', 'saw', 'a', 'police', 'officer', 'on', 'horseback', 'galloping', 'through', 'downtown']
# ['th', 'grade', 'was', 'so', 'great', 'though', 'we', 'all', 'said', 'wed', 'all', 'stay', 'close', 'We', 'should', 'all', 'get', 'together', 'ASAP']
# ['so', 'Its', 'not', 'the', 'same']
# ['got', 'that', 'vol', 'return', 'of', 'the', 'bodysnatchers', 'bumpin', 'Perfect', 'for', 'the', 'gym', 'Im', 'going', 'In', 'right', 'now']
# ['is', 'our', 'new', 'Twitter', 'pg', 'Follow', 'exciting', 'deals', 'ATX', 'challenges', 'insights', 'on', 'fashion', 'epicurean', 'entertainment', 'the', 'arts']
# ['Daddy', 'got', 'a', 'new', 'truck']
# ['Freakin', 'is', 'FLAWLESSin', 'every', 'way']
# ['hes', 'next', 'to', 'go', 'bro']
# ['Thanks', 'for', 'finally', 'providing', 'a', 'good', 'nights', 'rest', 'and', 'I', 'had', 'a', 'great', 'time', 'Hope', 'your', 'run', 'post', 'beers', 'was', 'good']
# ['I', 'love', 'my', 'momma']
# ['Hello', 'new', 'followers']
# ['Not', 'sure', 'Any', 'recommendations', 'RT', 'Hey', 'Chicago', 'What', 'are', 'you', 'eating', 'at', 'the', 'Taste', 'of', 'Chicago', 'this', 'weekend']
# ['Mayoral', 'Candidate', 'Forum', 'on', 'education', 'this', 'Thursday', 'January', 'pm', 'at', 'Warren', 'Easton', 'Canal', 'street']
# ['Ah', 'I', 'miss', 'that', 'place', 'so', 'much', 'We', 'def', 'need', 'to', 'do', 'another', 'road', 'trip', 'this', 'summer']
# ['Join', 'the', 'Maui', 'Mall', 'Shoppers', 'Club', 'at', 'wwwmauimallcom', 'We', 'give', 'away', 'three', 'great', 'prizes', 'monthly', 'including', 'gift', 'certificate', 'to', 'the', 'mall']
# ['busy', 'day', 'I', 'thought', 'called', 'about', 'Film', 'but', 'it', 'was', 'same', 'name', 'dude', 'who', 'is', 'a', 'set', 'medic', 'internmistakes']
# ['total', 'white', 'cat', 'move']
# ['I', 'actually', 'liked', 'Derek', 'Morris', 'as', 'a', 'Ranger']
# ['Twovsuns', 'massage', 'is', 'now', 'offering', 'couples', 'massage', 'What', 'a', 'great', 'way', 'to', 'start', 'off', 'your', 'valentines', 'day', 'Call', 'to', 'schedule', 'today']
# ['Stellar', 'of', 'to', 'reply', 'digiday', 'I', 'find', 'the', 'lack', 'of', 'women', 'in', 'marketingpr', 'leadership', 'interesting', 'its', 'an', 'area', 'of', 'research', 'for', 'me']
# ['Enter', 'to', 'win', 'an', 'Orioles', 'vintage', 'cap', 'by', 'email', 'or', 'tweet', 'the', 'answer', 'to', 'Which', 'Os', 'pitchers', 'hold', 'the', 'record', 'for', 'the', 'most', 'opening', 'day', 'starts']
# ['Prepare', 'for', 'testing', 'season', 'by', 'practicing', 'to', 'read', 'standardized', 'instructions', 'in', 'dry', 'monotone']
# ['What', 'Is', 'A', 'Life', 'Without', 'A', 'Purpose', 'What', 'Is', 'A', 'Purpose', 'Without', 'Love']
# ['got', 'to', 'fa', 'the', 'one', 'time', 'one', 'time', 'and', 'nope', 'that', 'shit', 'stressede', 'the', 'hell', 'out', 'boa']
# ['thats', 'the', 'beauty', 'of', 'selfpublishing', 'you', 'can', 'find', 'your', 'audience', 'without', 'publishing', 'types']
# ['im', 'waiting', 'patiently', 'for', 'the', 'videos', 'of', 'the', 'tram', 'ride', 'and', 'pics', 'at', 'Yoga']
# ['Congrats', 'to', 'Patti', 'Groff', 'CLM', 'on', 'winning', 'the', 'Spirit', 'of', 'ALA', 'Award', 'a', 'huge', 'honor', 'recognizing', 'leadership', 'and', 'dedication']
# ['Finally', 'Going', 'to', 'bed', 'Had', 'a', 'long', 'night', 'but', 'atleast', 'it', 'was', 'for', 'a', 'good', 'cause', 'RelayForLife']
# ['Haha', 'Works', 'for', 'me', 'sometimes']
# ['Send', 'details', 'and', 'I', 'can', 'post']
# ['Wearing', 'my', 'shirt', 'to', 'the', 'Skrillex', 'show', 'in', 'Indy', 'tonight', 'Already', 'got', 'a', 'lot', 'of', 'compliments']
# ['Howdy', 'Ali', 'good', 'to', 'meet', 'you', 'too']
# ['The', 'scent', 'of', 'Coco', 'Chanel', 'perfume', 'will', 'aways', 'flood', 'me', 'with', 'lovely', 'memories', 'of', 'my', 'dear', 'Aunt', 'Lynn']
# ['We', 'All', 'Got', 'That', 'One', 'Friend', 'whose', 'laugh', 'is', 'always', 'funnier', 'than', 'the', 'joke']
# ['Fact', 'Girls', 'have', 'a', 'lot', 'of', 'crushes', 'but', 'their', 'heart', 'only', 'belongs', 'to', 'one', 'guy']
# ['Number', 'one', 'SEO', 'mistake', 'Not', 'doing', 'on', 'page', 'keyword', 'optimization']
# ['Count', 'on', 'me', 'RT', 'better', 'get', 'your', 'own', 'party', 'started']
# ['I', 'hate', 'when', 'i', 'wear', 'bhoops', 'and', 'people', 'are', 'like', 'the', 'bigger', 'the', 'hole', 'the', 'bigger', 'the', 'hoe', 'and', 'im', 'just', 'like', 'Oo', 'bitch', 'try', 'me']
# ['Be', 'the', 'light', 'in', 'the', 'world', 'of', 'darkness']
# ['kids', 'Little', 'Stage', 'Puppet', 'Theater', 'Little', 'Stage', 'Puppet', 'Theater', 'Friday', 'May', 'at', 'PM', 'Monrovia', 'California', 'E', 'Colorado']
# ['lost', 'one', 'dream', 'so', 'now', 'im', 'gonna', 'pursue', 'an', 'even', 'greater', 'one']
# ['Interested', 'to', 'see', 'matte', 'football', 'helmets', 'next', 'year', 'Not', 'convinced', 'yet']
# ['oh', 'man', 'I', 'want', 'some', 'French', 'toast', 'so', 'bad', 'now']
# ['You', 'mean', 'a', 'winky', 'face', 'is', 'not', 'the', 'correct', 'use']
# ['omg', 'Jesus', 'loves', 'me', 'SO', 'much', 'that', 'sometimes', 'my', 'hair', 'falls', 'out', 'Then', 'I', 'pick', 'it', 'up', 'and', 'burn', 'it', 'as', 'an', 'offering', 'It', 'feels', 'so', 'nice']
# ['No', 'you', 'Not']
# ['Hi', 'there', 'Sueanne', 'Liking', 'the', 'newest', 'avatar', 'Getting', 'to', 'be', 'beach', 'weather', 'right']
# ['The', 'trip', 'home', 'feels', 'twice', 'as', 'long', 'Even', 'with', 'good', 'music', 'and', 'junk', 'food', 'Too', 'bad', 'I', 'dont', 'smoke', 'anymore']
# ['Thanks', 'for', 'ther', 'RT', 'about', 'Administrative', 'Professionals', 'Day']
# ['Tryin', 'to', 'stay', 'up', 'for', 'loiter', 'squad']
# ['looks', 'like', 'its', 'a', 'jquery', 'problem', 'in', 'thisselectMenuItem', 'this', 'refers', 'to', 'the', 'document', 'right']
# ['Can', 'I', 'get', 'a', 'refill']
# ['Sitting', 'in', 'the', 'doctors', 'office']
# ['ha', 'nah', 'that', 'aint', 'me']
# ['Hey', 'everyone', 'please', 'follow', 'one', 'of', 'the', 'best', 'metal', 'drummers', 'ever', 'Paul', 'Bostaph']
# ['Wow', 'Bollywood', 'and', 'Smash', 'are', 'still', 'trending', 'Thats', 'how', 'good', 'tonights', 'episode', 'of', 'smash', 'was']
# ['seriously', 'Ill', 'have', 'to', 'check', 'it', 'out']
# ['Just', 'saw', 'this', 'tweet', 'it', 'was', 'good', 'to', 'meet', 'you', 'too', 'Thank', 'you', 'so', 'much', 'for', 'your', 'support', 'MT']
# ['are', 'you', 'coming', 'to', 'get', 'Donovan']
# ['OK', 'just', 'asked', 'to', 'have', 'it', 'shipped', 'should', 'have', 'it', 'in', 'the', 'next', 'few', 'days']
# ['Engineering', 'Dev', 'Managerexcellent', 'leadership', 'opportunity', 'in', 'Bellevue']
# ['Sometimes', 'no', 'syntax', 'error', 'doesnt', 'equal', 'finished', 'it', 'equals', 'actually', 'beginning']
# ['Listening', 'to', 'The', 'Faint', 'always', 'makes', 'me', 'think', 'of', 'you', 'Its', 'not', 'bad', 'for', 'paperwriting', 'music']
# ['Sleep', 'with', 'one', 'eye', 'open']
# ['Loved', 'that', 'beer', 'thank', 'you', 'for', 'sharing']
# ['Successfully', 'set', 'up', 'Nokia', 'Education', 'Delivery', 'server', 'locally', 'MacBook', 'Pro', 'but', 'am', 'at', 'a', 'loss', 'for', 'user', 'guides']
# ['That', 'Alberto', 'is', 'part', 'of', 'our', 'secret', 'sauce', 'for', 'the', 'game', 'They', 'are', 'not', 'aware', 'as', 'that', 'could', 'bias', 'gameplay']
# ['hell', 'yeah', 'How', 'much', 'are', 'the', 'tickets']
# ['Thank', 'God', 'Lifetime', 'and', 'Thank', 'You', 'John', 'I', 'hope', 'the', 'show', 'lasts', 'forever', 'on', 'television', 'this', 'show', 'is', 'very', 'valuable', 'to', 'all', 'of', 'us']
# ['Teen', 'Wolf', 'Trailer', 'Omg', 'I', 'cant', 'wait', 'till', 'it', 'comes', 'back', 'on']
# ['U', 'Said', 'I', 'Will', 'BE', 'THERE', 'WITH', 'YOUBut', 'Wisconsin', 'NEEDS', 'U', 'NOW', 'GO', 'spend', 'campaign', 'there']
# ['Late', 'night', 'last', 'night']
# ['Pittsburgh', 'WPXI', 'interviewing', 'family', 'across', 'st', 'whose', 'chimney', 'fell', 'down', 'during', 'the', 'earthquake', 'Tempted', 'walk', 'out', 'dressed', 'in', 'my', 'Batman', 'outfit']
# ['Time', 'to', 'dream', 'bout', 'some', 'crazy', 'ishhh', 'goodnight']
# ['okaay', 'LOOOOL', 'i', 'still', 'remember', 'our', 'thoughts']
# ['its', 'my', 'fault', 'Im', 'sorry']
# ['hey', 'Clifbar', 'people', 'love', 'your', 'stuff', 'but', 'need', 'more', 'info', 'on', 'this', 'arsenic', 'in', 'organic', 'bar', 'business', 'in', 'the', 'news', 'today', 'Whats', 'your', 'take']
# ['Chicago', 'roadtrip', 'status', 'ACTIVE']
# ['Watched', 'Anatomy', 'of', 'a', 'Murder', 'tonight', 'Have', 'u', 'seen', 'it', 'Lates', 'courtroom', 'drama', 'that', 'you', 'would', 'surely', 'appreciate']
# ['Happy', 'Mothers', 'Day', 'all', 'Moms', 'from', 'me', 'FloboRojan', 'RT', 'Yearning', 'hear', 'well', 'done', 'good', 'faithful', 'servantFrom', 'my', 'Wife', 'cont']
# ['Hard', 'to', 'believe', 'but', 'The', 'Great', 'Online', 'formerly', 'ReignNet', 'has', 'accumulated', 'over', 'customers']
# ['Griffin', 'shoots', 'on', 'his', 'way', 'down', 'Irks', 'me']
# ['Hey', 'shawty', 'I', 'was', 'thinkin', 'of', 'you']
# ['theyre', 'gonna', 'win', 'just', 'to', 'fly', 'to', 'miami', 'tomorrow']
# ['sweet', 'Let', 'me', 'know', 'what', 'you', 'think', 'cant', 'wait', 'to', 'read', 'Humanize', 'by']
# ['Stop', 'trying', 'to', 'control', 'everything', 'and', 'just', 'let', 'go']
# ['It', 'is', 'an', 'absolutely', 'gorgeous', 'December', 'moon']
# ['God', 'has', 'so', 'many', 'amazing', 'plans', 'for', 'you', 'I', 'cant', 'wait', 'for', 'whats', 'to', 'come', 'and', 'some', 'new', 'music']
# ['yuptheres', 'all', 'kinds', 'of', 'sneezing', 'sniffles', 'in', 'my', 'house', 'lately']
# ['were', 'apart', 'at', 'a', 'ray']
# ['Holy', 'shit', 'my', 'mom', 'can', 'talk', 'About', 'the', 'SAME', 'DAMN', 'THING', 'That', 'everybody', 'already', 'knows']
# ['Coming', 'up', 'on', 'a', 'year', 'with', 'Twitter', 'and', 'not', 'much', 'to', 'show', 'for', 'it']
# ['Ok', 'I', 'need', 'a', 'remote', 'starter', 'asap']
# ['I', 'could', 'go', 'for', 'a', 'nice', 'post', 'dinner', 'cheese', 'plate', 'What', 'kind', 'of', 'host', 'are', 'you']
# ['Just', 'had', 'the', 'best', 'snow', 'cone', 'imperial', 'woodpecker', 'in', 'NYC', 'get', 'there']
# ['I', 'need', 'to', 'see', 'so', 'many', 'movies']
# ['Why', 'do', 'I', 'always', 'buy', 'the', 'biggest', 'wedding', 'gift']
# ['younger', 'guys', 'is', 'in', 'the', 'rotation', 'hopefully', 'behind', 'CC', 'and', 'then', 'RF', 'prob', 'with', 'Swisher', 'and', 'catcher']
# ['Thanks', 'Still', 'need', 'HelpSuggestions', 'I', 'had', 'another', 'commitments', 'Saturday', 'from', 'the', 'young', 'youth', 'group']
# ['I', 'deserve', 'to', 'know', 'its', 'GMO']
# ['Started', 'today', 'at', 'with', 'meditation', 'and', 'a', 'double', 'iced', 'espresso', 'I', 'think', 'I', 'have', 'found', 'the', 'magic', 'morning', 'combo']
# ['Its', 'your', 'blog', 'and', 'you', 'are', 'well', 'aware', 'of', 'the', 'link', 'Dont', 'play', 'dumb', 'with', 'me']
# ['Need', 'to', 'vacuum']
# ['The', 'panna', 'cotta', 'is', 'a', 'must', 'make']
# ['If', 'this', 'whole', 'journalism', 'thing', 'doesnt', 'work', 'out', 'I', 'think', 'I', 'now', 'know', 'what', 'I', 'want', 'my', 'second', 'career', 'to', 'be']
# ['because', 'theyre', 'bad', 'bitches', 'aka', 'bitches', 'doing', 'bad', 'close', 'to', 'the', 'lowest', 'female', 'life', 'form', 'next', 'to', 'jersey', 'chasers']
# ['Man', 'I', 'am', 'in', 'the', 'weeds', 'today', 'at', 'work', 'Someone', 'bring', 'me', 'ZKabob', 'and', 'brighten', 'my', 'day']
# ['Dont', 'forget', 'our', 'th', 'annual', 'CutsaCause', 'is', 'TOMORROW', 'from', 'Dont', 'miss', 'out', 'on', 'this', 'amazing', 'event', 'Call', 'to', 'book']
# ['At', 'first', 'I', 'wasnt', 'sure', 'because', 'Im', 'vegetarian', 'but', 'some', 'of', 'their', 'menu', 'does', 'look', 'good', 'especially', 'the', 'cheeses']
# ['Ill', 'go', 'without', 'before', 'i', 'beg', 'for', 'something']
# ['RT', 'And', 'IU', 'moves', 'on', 'to', 'the', 'next', 'round', 'of', 'the', 'tournament']
# ['Silverton', 'Skip', 'the', 'Strip', 'New', 'Years', 'Eve', 'celebration', 'wristband', 'all', 'you', 'can', 'drink']
# ['I', 'need', 'two', 'new', 'tires']
# ['NBA', 'FanNight', 'Chris', 'webber', 'my', 'dad', 'likes', 'your', 'glasses', 'DC']
# ['sometimes', 'you', 'gotta', 'do', 'stuff', 'you', 'really', 'dont', 'wanna', 'do']
# ['Sounds', 'good', 'bro']
# ['Im', 'digging', 'The', 'Offspring', 'right', 'now']
# ['Thanks', 'for', 'the', 'RT']
# ['Enjoy', 'this', 'sunny', 'day', 'with', 'a', 'smile', 'on', 'your', 'face', 'and', 'your', 'head', 'held', 'high', 'cuz', 'u', 'never', 'know', 'when', 'the', 'dark', 'clouds', 'will', 'roll', 'in']
# ['because', 'Why', 'Doesnt', 'look', 'like', 'a', 'keg', 'Guess', 'it', 'usually', 'smells', 'like', 'one', 'I', 'guess']
# ['No', 'worries', 'We', 'hope', 'you', 'find', 'ours', 'interesting', 'and', 'helpful', 'as', 'well']
# ['Spammers', 'Id', 'like', 'to', 'see', 'the', 'statistic', 'on', 'what', 'spammers', 'cost', 'american', 'small', 'businesses', 'in', 'a', 'dollar', 'amount', 'They', 'cost', 'me', 'so', 'much']
# ['Cory', 'Booker', 'is', 'on', 'my', 'tv']
# ['If', 'the', 'pencil', 'is', 'so', 'popular', 'then', 'why', 'is', 'it', 'number']
# ['plz', 'go', 'follow', 'she', 'follow', 'back', 'D', 'and', 'i', 'will', 'follow', 'you', 'too', 'D']
# ['Chasing', 'The', 'Sun', 'is', 'honestly', 'a', 'very', 'very', 'amazing', 'song', 'ITS', 'SO', 'ADDICTING', 'lol']
# ['Brandon', 'dont', 'joke', 'like', 'that']
# ['RT', 'Drake', 'Be', 'Sounding', 'Like', 'He', 'Be', 'Crying', 'His', 'Ass', 'Off', 'When', 'He', 'Be', 'Singing', 'Sometimes', 'lOl', 'hell', 'yeah']
# ['Motivation', 'and', 'inspiration', 'energize', 'people', 'not', 'by', 'pushing', 'them', 'in', 'the', 'right', 'direction', 'as', 'control', 'mechanisms', 'do', 'but', 'by', 'satisfying', 'basic']
# ['I', 'thought', 'you', 'were', 'strictly', 'Infrastructure', 'bro', 'You', 'doing', 'sharepoint', 'dev', 'roles', 'too', 'now']
# ['no', 'I', 'had', 'the', 'kids', 'The', 'ex', 'kinda', 'dropped', 'them', 'on', 'me']
# ['Playing', 'with', 'fire', 'again']
# ['Ads', 'When', 'Creatives', 'and', 'NonCreatives', 'Unite', 'is', 'March', 'th', 'Stay', 'tuned', 'in', 'to', 'Twitter', 'and', 'your', 'Email', 'for', 'more', 'information']
# ['awesome', 'Although', 'a', 'little', 'jealous', 'bout', 'the', 'Jordans', 'Haha']
# ['join', 'the', 'club', 'that', 'plays', 'unfollowfriday', 'every', 'week', 'It', 'relieves', 'stress']
# ['you', 'said', 'that', 'u', 'cant', 'say', 'boys', 'like', 'my', 'headyet', 'i', 'have', 'a', 'bfso', 'obviously', 'he', 'likes', 'my', 'head']
# ['Do', 'you', 'need', 'a', 'custom', 'welcome', 'gate', 'for', 'your', 'business', 'page', 'We', 'can', 'do', 'it', 'Need', 'social', 'media', 'management', 'We', 'can', 'handle', 'that', 'for', 'you', 'too']
# ['OR', 'Moons', 'Over', 'my', 'Hammy', 'lol', 'M']
# ['Missing', 'a', 'very', 'important', 'page', 'from', 'my', 'booking', 'notebookthis', 'isnt', 'good']
# ['gets', 'a', 'standing', 'ovation', 'on', 'Leno', 'Freedom', 'is', 'catching']
# ['Sorry', 'for', 'the', 'technical', 'difficulties', 'tonight', 'guys', 'One', 'day', 'soon', 'well', 'have', 'proper', 'working', 'equipment']
# ['it', 'should', 'keep', 'that', 'same', 'letter', 'everytime', 'u', 'plug', 'it', 'in']
# ['My', 'Facebook', 'doesnt', 'look', 'any', 'different', 'Can', 'I', 'say', 'Facebook', 'on', 'Twitter']
# ['The', 'thing', 'I', 'wish', 'I', 'could', 'say', 'to', 'you', 'but', 'knowing', 'I', 'wont']
# ['is', 'doing', 'some', 'work', 'Check', 'them', 'out']
# ['got', 'the', 'th', 'pickteam', 'leaguesomebody', 'help', 'me']
# ['you', 'never', 'know']
# ['That', 'song', 'still', 'gives', 'me', 'chills']
# ['Aight', 'heat', 'nation', 'victory', 'nite', 'nite', 'Lets', 'go', 'heat']
# ['I', 'love', 'talking', 'to', 'this', 'kidd']
# ['Thin', 'air', 'will', 'help', 'so', 'the', 'offense', 'wont', 'have', 'to', 'drive', 'as', 'far']
# ['Whoa', 'Whoa', 'Koalas', 'get', 'chlamydia']
# ['RIP', 'to', 'the', 'day', 'when', 'Titanic', 'sent', 'more', 'than', 'people', 'to', 'a', 'watery', 'grave']
# ['Lakers', 'would', 'do', 'well', 'to', 'keep', 'drawing', 'fouls', 'on', 'the', 'Thunder', 'bigs']
# ['is', 'there', 'a', 'worse', 'place', 'to', 'get', 'drafted', 'than', 'Cleveland']
# ['can', 'somebody', 'make', 'me', 'a', 'spaghetti', 'diagram', 'showing', 'the', 'connections', 'among', 'all', 'of', 'these', 'data', 'citation', 'programs', 'Overwhelming']
# ['Well', 'were', 'getting', 'close', 'to', 'completing', 'the', 'albumSee', 'the', 'journey']
# ['Going', 'to', 'bed', 'Night']
# ['Just', 'finished', 'one', 'thousand', 'giftswhat', 'a', 'read', 'Just', 'ordered', 'newhate', 'waiting']
# ['I', 'just', 'love', 'when', 'my', 'mother', 'forgets', 'to', 'pay', 'my', 'phone', 'bill', 'Sure', 'hope', 'I', 'dont', 'have', 'a', 'wreck', 'on', 'the', 'way', 'home', 'and', 'have', 'to', 'call']
# ['I', 'just', 'swabbed', 'for', 'Janet', 'Liang', 'tonight', 'And', 'Im', 'actually', 'home', 'tonight', 'to', 'listen']
# ['Josh', 'Hamilton', 'CRACKS', 'on', 'CJ', 'for', 'home', 'runs', 'on', 'the', 'season', 'Dude', 'is', 'in', 'a', 'ZONE']
# ['Does', 'anyone', 'get', 'blown', 'out', 'on', 'the', 'road', 'more', 'often', 'than', 'the', 'Lakers']
# ['girls', 'over', 'should', 'stick', 'to', 'sweats', 'and', 'bags', 'over', 'their', 'heads']
# ['Is', 'your', 'last', 'name', 'Trump', 'Mine', 'got', 'for', 'the', 'first', 'for', 'each', 'thereafter']
# ['haha', 'its', 'the', 'culture', 'B', 'haha']
# ['LA', 'MUJER', 'DE', 'IVAN', 'PM', 'Screened', 'as', 'part', 'of', 'The', 'New', 'Chilean', 'Directors', 'Showcase']
# ['haha', 'your', 'full', 'of', 'it', 'Its', 'a', 'gray', 'day', 'and', 'Im', 'stressed', 'but', 'doing', 'OK', 'Ha']
# ['Well', 'there', 'might', 'not', 'be', 'any', 'crying', 'in', 'baseball', 'but', 'there', 'is', 'a', 'great', 'deal', 'of', 'it', 'in', 'skiing']
# ['I', 'would', 'love', 'to', 'connect', 'sometime', 'Where', 'are', 'you', 'located']
# ['yessir', 'you', 'are', 'correct']
# ['I', 'want', 'steak', 'and', 'crab', 'so', 'bad', 'right', 'now', 'Im', 'thinking', 'a', 'late', 'night', 'grilling', 'session', 'later']
# ['You', 'will', 'absolutely', 'love', 'it', 'after', 'the', 'first', 'pages', 'So', 'suck', 'it', 'up', 'and', 'get', 'that', 'far', 'It', 'turns', 'on', 'a', 'dime']
# ['You', 'know', 'football', 'isnt', 'nearly', 'as', 'fun', 'to', 'watch', 'when', 'beer', 'isnt', 'involved']
# ['Being', 'abused']
# ['I', 'found', 'Toure', 'Neblett', 'much', 'less', 'of', 'a', 'jerk', 'than', 'one', 'name', 'Toure', 'the', 'delusional', 'ego', 'maniac', 'with', 'an', 'opinion', 'on', 'everything']
# ['Anyone', 'out', 'there', 'looking', 'to', 'buy', 'hunting', 'land', 'in', 'Northern', 'Central', 'Wisconsin', 'this', 'fall']
# ['OMG', 'MediaTemple', 'NameSevers', 'are', 'down', 'Somebodys', 'going', 'to', 'be', 'in', 'trouble']
# ['Mathematics', 'is', 'made', 'of', 'percent', 'formulas', 'percent', 'proofs', 'and', 'percent', 'imagination', 'And', 'mathematicians', 'prove', 'this', 'all', 'the', 'time']
# ['can', 'I', 'set', 'up', 'an', 'interview', 'with', 'you', 'guys']
# ['wow', 'I', 'have', 'snake', 'bites', 'again']
# ['Phillip', 'Humber', 'threw', 'a', 'perfect', 'game', 'will', 'never', 'stop', 'talking', 'about', 'it', 'haha']
# ['Happy', 'Casimir', 'Pulaski', 'Day', 'Only', 'in', 'Illinois']
# ['Guys', 'make', 'me', 'upset']
# ['Is', 'everyone', 'Getting', 'Along']
# ['So', 'its', 'worth', 'watching', 'So', 'afraid', 'to', 'commit', 'to', 'another', 'show']
# ['Yes', 'you', 'should', 'be', 'mean', 'to', 'the', 'foster', 'dog', 'so', 'he', 'doesnt', 'like', 'you', 'Thats', 'the', 'ticket']
# ['aw', 'Okay']
# ['I', 'want', 'to', 'get', 'followers', 'already', 'Follow', 'me']
# ['i', 'guess', 'they', 'think', 'they', 'doin', 'somethin', 'by', 'changing', 'my', 'fb', 'password', 'nd', 'im', 'the', 'Lil', 'Kid', 'lmaooo']
# ['Id', 'like', 'to', 'know', 'how', 'much', 'household', 'help', 'had', 'when', 'the', 'boys', 'were', 'infants', 'in', 'school']
# ['iv', 'never', 'felt', 'this', 'for', 'any', 'guy', 'u', 'must', 'be', 'special', 'its', 'a', 'thing', 'called', 'true', 'love']
# ['I', 'didnt', 'say', 'it', 'wasnt', 'a', 'good', 'question', 'I', 'said', 'its', 'not', 'a', 'good', 'question', 'on', 'Mothers', 'Day']
# ['Surrendering', 'isnt', 'just', 'about', 'letting', 'goIts', 'about', 'letting', 'God', 'I', 'surrender', 'all']
# ['Rooney', 'Rule', 'You', 'should', 'start', 'eating', 'right', 'getting', 'sleep', 'and', 'exercising', 'soon', 'because', 'soon', 'it', 'will', 'be', 'too', 'late']
# ['Richard', 'Welsh', 'is', 'Steves', 'Dad', 'He', 'is', 'hoping', 'TeamSoaringHigh', 'from', 'Colorado', 'where', 'the', 'Welsh', 'family', 'lived', 'a', 'country', 'road', 'or', 'from', 'each', 'other']
# ['G', 'CERTIFIED', 'WET', 'TSHIRT', 'CONTEST', 'FRIDAY', 'CLUB', 'DRAMA', 'WANT', 'TO', 'GET', 'IN', 'FOR', 'FREE', 'TXT', 'ME', 'I', 'WILL', 'TELL', 'YOU', 'HOW']
# ['Startingnow', 'I', 'want', 'ALL', 'those', 'girls', 'of', 'the', 'world', 'to', 'know', 'that', 'they', 'are', 'beautiful', 'and', 'that', 'there', 'should', 'notbebulling', 'and', 'it', 'should', 'stop']
# ['I', 'miss', 'Ryan', 'Dunn']
# ['What', 'a', 'beautiful', 'fall', 'night', 'in', 'Seattle', 'I', 'love', 'this', 'time', 'of', 'year']
# ['Now', 'that', 'everyone', 'has', 'graduated', 'Im', 'off', 'to', 'never', 'never', 'land']
# ['My', 'Name', 'Is', 'MAHATAA', 'is', 'BOOK', 'OF', 'THE', 'MONTH', 'at', 'Agape', 'for', 'the', 'month', 'of', 'February', 'leading', 'into', 'book', 'signing', 'in', 'midMarch', 'See', 'you', 'then']
# ['good', 'cause', 'the', 'cowboys', 'could', 'use', 'him', 'in', 'two', 'years']
# ['San', 'diego', 'mayor', 'talking', 'about', 'the', 'necessity', 'of', 'art', 'despite', 'hard', 'times']
# ['Some', 'things', 'are', 'easier', 'said', 'than', 'done']
# ['Thanks', 'for', 'the', 'RT', 'I', 'hope', 'all', 'is', 'well', 'with', 'you']
# ['Kind', 'of', 'wish', 'I', 'wasnt', 'going', 'to', 'prom']
# ['Lol', 'Shep', 'Jr', 'dont', 'care']
# ['ALL', 'seized', 'Full', 'Tilt', 'Poker', 'funds', 'incl', 'payment', 'processors', 'should', 'be', 'used', 'to', 'reimburse', 'players', 'THX']
# ['Congrats', 'to', 'all', 'who', 'made', 'last', 'night', 'a', 'selloutcome']
# ['yikessince', 'RIM', 'has', 'introduced', 'models', 'A', 'Boggle', 'of', 'Blackberrys', 'nytimstKKhZ']
# ['IDIOT', 'Ban', 'him']
# ['Ok', 'I', 'need', 'kush', 'rehab', 'real', 'shit']
# ['RT', 'it', 'would', 'be', 'amazing', 'and', 'the', 'best', 'thing', 'yet', 'if', 'u', 'were', 'to', 'follow', 'me', 'yee']
# ['Taking', 'orders', 'for', 'custom', 'clips', 'pic', 'sets', 'and', 'webcam', 'shows']
# ['Lobby', 'of', 'Marriott', 'playing', 'Bruce', 'Hungry', 'Heart', 'waiting', 'for', 'NJ', 'crowd', 'to', 'arrive']
# ['I', 'didnt', 'get', 'home', 'until', 'the', 'saw', 'the', 'sun', 'coming', 'up', 'I', 'went', 'hard', 'last', 'night']
# ['ugh', 'i', 'knowlong', 'night', 'Smh']
# ['Sad', 'The', 'guy', 'who', 'created', 'the', 'Mustang', 'Cobra', 'passed', 'away', 'today', 'My', 'favorite', 'car']
# ['UK', 'sucks', 'UofL', 'all', 'day']
# ['One', 'day', 'dude', 'You', 'guys', 'need', 'to', 'come', 'through', 'Canada', 'already', 'haha']
# ['Tommorow', 'is', 'Bday', 'nd', 'Everyone', 'should', 'Wish', 'Her', 'A', 'Good', 'One', 'She', 'is', 'One', 'Of', 'Are', 'Biggest', 'Supporters', 'So', 'SO', 'Nd', 'Love', 'You', 'Pintos']
# ['Take', 'a', 'risk', 'today', 'Cooperation', 'is', 'key', 'to', 'executing', 'complex', 'business', 'tasks', 'but', 'competition', 'is', 'at', 'the', 'heart', 'of', 'innovation']
# ['Brewers', 'upcoming', 'series', 'this', 'week', 'games', 'at', 'NY', 'Mets', 'games', 'at', 'Houston', 'games', 'vs', 'Twins']
# ['life', 'is', 'too', 'short', 'gotta', 'live', 'it', 'longChris', 'Rene', 'love', 'it']
# ['Started', 'revising', 'the', 'chapter', 'Your', 'suggestions', 'are', 'helping', 'this', 'argument', 'along', 'so', 'well', 'I', 'cant', 'thank', 'you', 'enough']
# ['I', 'know', 'that', 'But', 'others', 'dont']
# ['Have', 'you', 'given', 'your', 'presentation', 'yet', 'Hows', 'the', 'conference', 'going']
# ['I', 'look', 'all', 'summery', 'and', 'like', 'a', 'volleyball', 'player', 'made', 'my', 'day']
# ['YeaI', 'curse', 'like', 'a', 'fucking', 'sailor', 'But', 'Im', 'working', 'on', 'it', 'lol']
# ['Dream', 'interpretation', 'Its', 'about', 'sex', 'Thatll', 'be']
# ['send', 'the', 'pizza', 'in', 'the', 'mail']
# ['I', 'guess', 'so', 'Sure', 'hope', 'its', 'soon', 'enough']
# ['Up', 'early', 'thiis', 'morning', 'nd', 'now', 'its', 'back', 'to', 'the', 'studio', 'Got', 'a', 'couple', 'traxxs', 'to', 'listen', 'too', 'nd', 'possibly', 'layiin', 'dwn', 'a', 'track', 'WORD']
# ['Another', 'Great', 'Workout', 'This', 'AM', 'Just', 'Smashed', 'This', 'Breakfast', 'Now', 'Headed', 'n', 'to', 'the', 'office', 'for', 'a', 'Productive', 'Work', 'Day']
# ['ICantStandPeople', 'who', 'think', 'they', 'know', 'it', 'all', 'or', 'start', 'a', 'conversation', 'but', 'dont', 'keep', 'it', 'going']
# ['Why', 'do', 'the', 'last', 'words', 'of', 'tweet', 'line', 's', 'repeat', 'at', 'start', 'of', 'line', 's']
# ['RT', 'probably', 'a', 'defense', 'mechanism', 'against', 'dissonance', 'from', 'viewing', 'oneself', 'as', 'civilized', 'while', 'acting', 'savagebarbaric', 'toward', 'others']
# ['I', 'am', 'so', 'glad', 'you', 'like', 'it', 'as', 'much', 'as', 'I', 'do']
# ['I', 'love', 'getting', 'drunk', 'on', 'occasions', 'Are', 'u', 'out', 'or', 'in', 'home']
# ['talking', 'about', 'moving', 'beyond', 'the', 'idea', 'of', 'giving', 'your', 'reputation', 'to', 'a', 'social', 'network', 'and', 'letting', 'them', 'monetize', 'it']
# ['Melo', 'is', 'a', 'scorer', 'nobody', 'can', 'stop', 'him', 'at', 'all', 'He', 'is', 'usually', 'threading', 'scorer', 'not', 'this', 'year', 'though']
# ['following', 'u']
# ['I', 'want', 'a', 'large', 'cherry', 'berry', 'chiller']
# ['screw', 'everyone', 'and', 'come', 'to', 'Baylor']
# ['So', 'happy', 'to', 'finally', 'be', 'home', 'I', 'missed', 'my', 'family', 'so', 'much']
# ['youve', 'been', 'fed', 'a', 'complete', 'diet', 'of', 'propaganda', 'your', 'whole', 'lifenow', 'how', 'will', 'you', 'votethe', 'only', 'way', 'you', 'have', 'learned', 'thru', 'inculcation']
# ['I', 'likee', 'both', 'of', 'them', 'o']
# ['TWEET', 'this', 'AmpTopTrend', 'with', 'the', 'name', 'of', 'the', 'song', 'or', 'artist', 'you', 'want', 'to', 'hear', 'on', 'Every', 'hour', 'you', 'choose', 'a', 'new', 'song']
# ['i', 'cant', 'even', 'begin', 'to', 'tell', 'you', 'the', 'feeling', 'i', 'getwhen', 'hearing', 'my', 'beats', 'playbetter', 'than', 'any', 'drug', 'McM']
# ['is', 'on', 'Tuesday', 'and', 'watching', 'A', 'Man', 'Apartone', 'of', 'my', 'favorites']
# ['Beyond', 'frustrated', 'Shit']
# ['no', 'way', 'you', 'looked', 'like', 'a', 'boy', 'BUT', 'I', 'feel', 'you', 'sister', 'Judy', 'cuts', 'my', 'hair', 'and', 'shes', 'a', 'bad', 'ass', 'She', 'will', 'make', 'you', 'look', 'great']
# ['hey', 'whyd', 'you', 'decide', 'to', 'join', 'twitter', 'hopefully', 'i', 'can', 'be', 'your', 'first', 'reply']
# ['Assert', 'your', 'right', 'to', 'make', 'a', 'few', 'mistakes', 'If', 'people', 'cant', 'accept', 'your', 'imperfections', 'thats', 'their', 'fault']
# ['I', 'wuvvvv', 'you']
# ['I', 'knew', 'something', 'was', 'going', 'to', 'go', 'wrong']
# ['I', 'will', 'happily', 'provide', 'cookies', 'in', 'exchange', 'for', 'answers', 'Very', 'sad', 'to', 'hear', 'about', 'Awake', 'you', 'are', 'an', 'exceptional', 'writer']
# ['hahah', 'Its', 'a', 'heart']
# ['Hahaha', 'Im', 'sure', 'hed', 'indulge', 'you', 'For', 'some', 'reason', 'Id', 'love', 'to', 'also', 'hear', 'Tim', 'Burtons', 'opinion', 'about', 'Inception', 'P']
# ['She', 'said', 'put', 'a', 'candle', 'on', 'my', 'back', 'baby', 'blow', 'it', 'Ill', 'blow', 'dat', 'back', 'out', 'aaiight']
# ['Romney', 'shouldnt', 'feel', 'too', 'bad', 'about', 'getting', 'whipped', 'today', 'He', 'did', 'end', 'up', 'winning', 'American', 'Samoa', 'so', 'hes', 'got', 'that', 'going', 'for', 'him']
# ['These', 'are', 'the', 'days', 'of', 'miracles', 'and', 'wonders', 'Believe', 'and', 'it', 'shall', 'be']
# ['Forgiveness', 'comes', 'by', 'growth', 'Your', 'growth']
# ['I', 'used', 'to', 'give', 'a', 'damn', 'but', 'Ill', 'never', 'give', 'a', 'fuck']
# ['Tablas', 'Creek', 'Vermentino', 'Delightfully', 'true', 'to', 'type', 'Sweet', 'tart', 'balanced', 'Crisp', 'bit', 'spritzy', 'green', 'apple', 'pear', 'citrus', 'pts']
# ['Ill', 'just', 'have', 'the', 'salad']
# ['i', 'dnt', 'have', 'fb', 'sry', 'but', 'if', 'i', 'did', 'i', 'would', 'ill', 'RT']
# ['USDA', 'Completely', 'Deregulates', 'Genetically', 'Engineered', 'AlfalfaWTF']
# ['Live', 'music', 'tonight', 'in', 'for', 'a', 'drink', 'or', 'two', 'Dont', 'forget', 'free', 'parking']
# ['Vacay', 'cant', 'come', 'soon', 'enoughugh']
# ['Whats', 'up', 'twitter', 'world']
# ['Home', 'from', 'SJ', 'Gotta', 'get', 'some', 'rest', 'for', 'the', 'am', 'Black', 'Friday', 'shopping', 'trip', 'with', 'the', 'man', 'I', 'love', 'Mastercard', 'I', 'mean', 'Matt', 'LOL', 'z']
# ['EllenRTme', 'day', 'Its', 'been', 'such', 'a', 'great', 'weekend', 'I', 'have', 'no', 'iPhone', 'so', 'this', 'is', 'a', 'for']
# ['CONGRATS', 'Plan', 'on', 'directing', 'or', 'being', 'a', 'DP']
# ...
# ['I', 'dont', 'know', 'if', 'you', 'realize', 'it', 'but', 'you', 'just', 'called', 'H', 'a', 'woman']
# ['and', 'I', 'never', 'got', 'an', 'email', 'inviting', 'me', 'to', 'the', 'K', 'Freerolls', 'at', 'K']
# ['I', 'bet', 'its', 'hard', 'to', 'feel', 'finished', 'and', 'fully', 'prepared']
# ['When', 'your', 'phone', 'decides', 'to', 'meet', 'your', 'face', 'while', 'texting', 'in', 'bed']
# ['I', 'DID', 'in', 'fact', 'just', 'had', 'no', 'idea', 'that', 'was', 'Mongolian', 'too', 'RT', 'thx', 'for', 'coming', 'Did', 'you', 'try', 'the', 'Mongolian', 'Vodka']
# ['Ahh', 'well', 'if', 'I', 'dont', 'like', 'it', 'Im', 'going', 'that', 'colour', 'L']
# ['The', 'media', 'whore', 'in', 'me', 'is', 'debating', 'whether', 'to', 'go', 'to', 'Sobo', 'or', 'British', 'Bulldog', 'on', 'Saturday', 'to', 'try', 'and', 'get', 'my', 'third', 'straight', 'world', 'cup', 'news', 'story']
# ['Kiddo', 'wants', 'to', 'know', 'if', 'youve', 'met', 'any', 'fairies', 'We', 'both', 'love', 'the', 'garden']
# ['My', 'knee', 'felt', 'good', 'during', 'yesterdays', 'half', 'so', 'Im', 'giving', 'myself', 'the', 'green', 'light', 'to', 'start', 'training', 'conservatively', 'Yay']
# ['Watching', 'the', 'vow']
# ['Lenny', 'Kravitzs', 'daughter', 'Zoe', 'is', 'so', 'pretty', 'badd', 'ass', 'Nice']
# ['you', 'deviated', 'from', 'schedule', 'the', 'beef', 'rib', 'tweets', 'are', 'going', 'to', 'kill', 'you']
# ['can', 'you', 'come', 'steal', 'my', 'coffee', 'so', 'i', 'can', 'kiss', 'you']
# ['please', 'make', 'sure', 'your', 'boys', 'cover', 'today']
# ['I', 'often', 'wonder', 'why', 'it', 'always', 'seems', 'that', 'assholes', 'make', 'it', 'to', 'the', 'top', 'hmm', 'glad', 'I', 'am', 'one']
# ['we', 'tried', 'that', 'already', 'if', 'you', 'wanna', 'get', 'better', 'you', 'find', 'a', 'wayand', 'u', 'pressure', 'your', 'boys', 'to', 'get', 'there']
# ['heyo', 'whats', 'up', 'buddy']
# ['Stop', 'into', 'W', 'Madison', 'for', 'a', 'VersaSpa', 'spray', 'tan', 'Perfect', 'way', 'to', 'prepare', 'for', 'the', 'weekend']
# ['I', 'wish', 'I', 'could', 'chill', 'with', 'someone', 'tonight', 'or', 'something', 'to', 'be', 'honest', 'Im', 'kinda', 'bored']
# ['Ooh', 'I', 'havent', 'had', 'Chinese', 'in', 'a', 'long', 'time', 'That', 'would', 'be', 'good', 'Thanks', 'How', 'have', 'you', 'been']
# ['thanks', 'for', 'the', 'follow', 'you', 'had', 'me', 'at', 'dryaged', 'prime', 'steaks']
# ['KARAOKE', 'NIGHT', 'TONIGHT']
# ['Love', 'that', 'TopGear', 'is', 'back', 'on', 'TV', 'on', 'the']
# ['OO', 'is', 'standing', 'right', 'next', 'to', 'mee', 'D', 'OMFGGGG']
# ['i', 'texted', 'to', 'the', 'number']
# ['Free', 'Summer', 'Crossword', 'Puzzle', 'from', 'Desirable', 'Magazine', 'Issue']
# ['hey', 'can', 'i', 'spend', 'the', 'night', 'with', 'you', 'friday']
# ['were', 'at']
# ['Why', 'is', 'my', 'room', 'so', 'hot']
# ['you', 'taste', 'like', 'sunlight', 'and', 'strawberry', 'bubblegum', 'you', 'make', 'my', 'heart', 'beat', 'fastermattnathanson', 'redbull']
# ['Tline', 'was', 'sick', 'today', 'Lots', 'of', 'fresh', 'POW', 'Hittin', 'it', 'again', 'morrow', 'b', 'we', 'head', 'to', 'Epic', 'the', 'Jibba', 'jam', 'Check', 'us', 'out', 'morrow', 'handin', 'out', 'shwag']
# ['I', 'cant', 'fuckinnn', 'wait', 'for', 'the', 'NFL', 'season', 'to', 'start', 'it', 'needs', 'to', 'be', 'September', 'already']
# ['WaitI', 'just', 'realized', 'that', 'Ive', 'came', 'really', 'close', 'to', 'either', 'seeingmeeting', 'all', 'my', 'favorite', 'musicians', 'WHAT', 'IS', 'THIS', 'FUCKERY']
# ['Yarn', 'graffiti', 'thats', 'it', 'exactly']
# ['right', 'when', 'the', 'song', 'starts', 'yep']
# ['Tell', 'me', 'does', 'this', 'smell', 'like', 'chlorophorm']
# ['Poynters', 'Iron', 'Pit', 'Gym', 'Richmond', 'Ky', 'has', 'hour', 'personal', 'training', 'sessions', 'for', 'Get', 'in', 'get', 'shredded']
# ['Automated', 'Essay', 'Scoringagreed', 'that', 'the', 'current', 'NYTimes', 'and', 'Edweek', 'articles', 'in', 'response', 'to', 'the', 'findings', 'miss', 'the', 'point']
# ['CYCA', 'has', 'really', 'been', 'thinning', 'out', 's', 'up']
# ['When', 'I', 'visit', 'the', 'monastery', 'Ill', 'have', 'to', 'ask', 'Mother', 'Hildegard', 'if', 'shes', 'seen', 'Sister', 'Act', 'Back', 'In', 'The', 'Habit']
# ['Right', 'now', 'it', 'is', 'the', 'first', 'time', 'every', 'single', 'one', 'of', 'our', 'sleeping', 'bags', 'are', 'being', 'used', 'by', 'a', 'kid', 'on', 'course', 'out', 'of', 'the', 'Urban', 'Center']
# ['RIP', 'DustinHengst', 'of', 'Damone', 'and', 'Bleu', 'Will', 'never', 'forget', 'all', 'the', 'fun', 'we', 'had', 'back', 'in', 'the', 'day', 'in', 'Boston', 'Sad', 'day', 'for', 'friends', 'family', 'fans']
# ['Charlie', 'Sheen', 'looks', 'ill']
# ['We', 'also', 'have', 'Bacon', 'and', 'Eggs', 'Chicken', 'piccata', 'lunchdinner', 'Soup', 'of', 'the', 'Dayvegetable', 'barley']
# ['That', 'was', 'in', 'my', 'weezy', 'voice', 'btw']
# ['Thats', 'on', 'June', 'th', 'right', 'We', 'can', 'check', 'into', 'it', 'for', 'you', 'Just', 'give', 'us', 'a', 'bit']
# ['Helium', 'Pats', 'Trick']
# ['Im', 'incredibly', 'flattered', 'Its', 'not', 'that', 'hard', 'or', 'time', 'consuming', 'promise', 'Just', 'eat', 'right', 'and', 'exercise', 'regularly']
# ['alas', 'no', 'encore', 'until', 'next', 'year']
# ['Sue', 'her', 'for', 'suing', 'the', 'gilr', 'that', 'slapped', 'her', 'Lawd', 'have', 'mercy']
# ['I', 'dont', 'remember', 'Seau', 'having', 'any', 'concussions', 'but', 'this', 'strikes', 'me', 'as', 'another', 'in', 'a', 'line', 'of', 'recent', 'football', 'suicides', 'who', 'did', 'Extremely', 'sad']
# ['of', 'course', 'We', 'are', 'huge', 'fans', 'of', 'yours']
# ['We', 'think', 'a', 'perfect', 'weekend', 'would', 'include', 'a', 'show', 'Stage']
# ['yes', 'I', 'do']
# ['of', 'course', 'this', 'could', 'also', 'be', 'due', 'to', 'drained', 'gadget', 'batteries']
# ['I', 'bet', 'you', 'like', 'Asians', 'The', 'power', 'of', 'the', 'Asian']
# ['Pinnacle', 'Bank', 'sees', 'st', 'quarter', 'earnings', 'improve', 'over', 'weak']
# ['Traffic', 'in', 'LA', 'sucks', 'ass', 'today', 'Apparently', 'if', 'its', 'windy', 'people', 'cant', 'drive']
# ['Do', 'you', 'know', 'what', 'I', 'hate', 'Paying', 'bills']
# ['Chi', 'city']
# ['Im', 'so', 'tired']
# ['FF', 'new', 'old', 'Tweetforest', 'friends']
# ['That', 'was', 'fun']
# ['James', 'Harden', 'is', 'the', 'man']
# ['OMG', 'Hulk', 'its', 'morning', 'now', 'I', 'couldnt', 'sleep', 'so', 'got', 'on', 'Twitter', 'GOOD', 'MORNING', 'FROM', 'DALLAS', 'and', 'a', 'huge', 'hulkmaniac']
# ['Thanks', 'Dan']
# ['JULIA', 'IT', 'WAS', 'SO', 'BEAUTIFUL', 'AND', 'PERFECT']
# ['Hurt', 'myself', 'again', 'today', 'and', 'the', 'worst', 'part', 'is', 'theres', 'noone', 'else', 'to', 'blame']
# ['Thanks', 'for', 'the', 'mention', 'Much', 'appreciated']
# ['You', 'Are', 'My', 'Bestie', 'Right', 'Or', 'Are', 'You', 'A', 'Different', 'Person']
# ['lmfaooooooooooo', 'i', 'love', 'you']
# ['haha', 'to', 'me', 'it', 'was', 'kinda', 'hot', 'kidding']
# ['Im', 'really', 'impressed', 'with', 'youre', 'handling', 'Seriously', 'looking', 'into', 'your', 'services', 'for', 'my', 'domain', 'names', 'Thank', 'you']
# ['My', 'kitchen', 'sink', 'is', 'clogged', 'like', 'Paula', 'Deans', 'arteries', 'right', 'now', 'I', 'really', 'dont', 'want', 'to', 'go', 'to', 'Lowes', 'right', 'now']
# ['I', 'knew', 'there', 'was', 'a', 'reason', 'why', 'I', 'stopped', 'eating', 'there', 'Now', 'I', 'know', 'what', 'it', 'was']
# ['Great', 'call', 'with', 'Dallas', 'thanks', 'so', 'much', 'for', 'sharing', 'all', 'the', 'wonderful', 'info']
# ['wssmiami', 'Less', 'chatter', 'and', 'more', 'conversation', 'collaboration', 'and', 'action', 'success']
# ['The', 'mind', 'cannot', 'see', 'things', 'objectively', 'until', 'theyre', 'on', 'paper', 'on', 'journaling']
# ['I', 'SHOLL', 'am']
# ['He', 'like', 'a', 'ray', 'lewis', 'RT', 'Panthers', 'gotta', 'White', 'London', 'Fletcher', 'in', 'other', 'words', 'a', 'tackle', 'machine']
# ['Mosquitos', 'keep', 'suiciding', 'in', 'my', 'drinks']
# ['Bon', 'Voyage', 'my', 'friend', 'Have', 'a', 'great', 'time']
# ['does', 'that', 'help', 'with', 'concentration']
# ['THANKS', 'SO', 'MUCH', 'I', 'am', 'sitting', 'in', 'a', 'school', 'librarian', 'forum', 'right', 'now', 'at', 'conference', 'in', 'Philly', 'Messaging', 'you', 'address', 'next']
# ['i', 'better', 'be', 'right', 'P']
# ['RT', 'Pride', 'in', 'Detroit', 'is', 'something', 'you', 'have', 'in', 'your', 'You', 'cant', 'buy', 'it', 'or', 'sell', 'it', 'but', 'you', 'can', 'give', 'it', 'away', 'on', 'FB', 'wall']
# ['the', 'centers', 'are', 'not', 'bad', 'They', 'taste', 'of', 'But', 'its', 'a', 'hard', 'core', 'so', 'they', 'get', 'cut', 'out', 'Lol']
# ['Episode', 'did', 'drop', 'wanterful', 'at', 'the', 'last', 'of', 'talesofwant']
# ['lol', 'yeah', 'yo', 'I', 'was', 'heated', 'when', 'I', 'found', 'out', 'it', 'was', 'the', 'last', 'episode', 'they', 'better', 'do', 'a', 'minuet', 'recap', 'cause', 'I', 'forgot']
# ['I', 'dont', 'really', 'know', 'anybody', 'on', 'Mill', 'eitherfelt', 'pointless', 'walking', 'around', 'and', 'listening', 'to', 'dumbass', 'scumbag', 'steves', 'speak']
# ['I', 'work', 'hours', 'a', 'week', 'to', 'be', 'this', 'poor']
# ['what', 'you', 'think', 'bout', 'the', 'pacers']
# ['I', 'love', 'how', 'they', 'can', 'buy', 'a', 'pair', 'of', 'sunglasses', 'then', 'ignore', 'me', 'when', 'I', 'say', 'I', 'need', 'clothes']
# ['So', 'excited', 'Going', 'to', 'for', 'dinner', 'tonight', 'First', 'time', 'CANNOT', 'WAIT']
# ['dats', 'whats', 'up', 'pretty', 'lady', 'n', 'Im', 'doin', 'good', 'just', 'working', 'on', 'sum', 'music', 'stuff']
# ['Luntsford', 'is', 'all', 'packed', 'up']
# ['Nerad', 'explains', 'this', 'is', 'a', 'preliminary', 'plan', 'to', 'be', 'fleshed', 'out', 'in', 'community', 'groups', 'MMSDinputsession']
# ['Just', 'threw', 'Renes', 'blue', 'corpse', 'on', 'the', 'remaining', 'embers', 'At', 'least', 'Comcasts', 'got', 'survival', 'game']
# ['Youre', 'such', 'an', 'elegant', 'well', 'MANicured', 'lady']
# ['This', 'is', 'a', 'test', 'post', 'to', 'Facebook']
# ['Im', 'in', 'the', 'woods', 'so', 'much', 'I', 'can', 'tell', 'you', 'which', 'plants', 'are', 'edible', 'Lee', 'Trevino']
# ['Grilling', 'outside', 'with', 'my', 'parents', 'at', 'the', 'Jersey', 'shore', 'We', 'would', 'grill', 'lobster', 'and', 'corn', 'in', 'the', 'summer']
# ['Drawing', 'is', 'the', 'honesty', 'of', 'the', 'art', 'There', 'is', 'no', 'possibility', 'of', 'cheating', 'It', 'is', 'either', 'good', 'or', 'bad', 'Salvador', 'Dali']
# ['thank', 'for', 'the', 'following', 'your', 'music', 'rocks', 'my', 'world']
# ['You', 'can', 'put', 'me', 'in', 'a', 'library', 'all', 'day', 'and', 'I', 'wont', 'mind']
# ['im', 'in', 'just', 'gotta', 'run', 'it', 'by', 'miranda', 'Im', 'kidding']
# ['Saw', 'the', 'trailer', 'not', 'the', 'film', 'thanks', 'for', 'the', 'reminder']
# ['Ohhow', 'did', 'i', 'get', 'here', 'What', 'will', 'i', 'do', 'when', 'its', 'done', 'I', 'am', 'lonely', 'Not', 'the', 'peaceful', 'kind', 'The', 'heart', 'hurting', 'kind']
# ['u', 'better', 'play', 'me', 'back', 'in', 'that', 'damn', 'drawing', 'game']
# ['oh', 'Im', 'trying', 'so', 'hard', 'but', 'its', 'like', 'Im', 'sitting', 'at', 'home', 'n', 'theyre', 'bringing', 'drama', 'to', 'me', 'I', 'cant', 'take', 'that', 'lightly', 'u', 'know']
# ['You', 'know', 'that', 'storage', 'never', 'sleeps', 'Looking', 'forward', 'to', 'working', 'with', 'you', 'againmoreoften']
# ['awesome', 'followed', 'me', 'Check', 'em', 'out', 'if', 'u', 'dont', 'know', 'who', 'they', 'are', 'Yall', 'know', 'I', 'have', 'good', 'music', 'taste', 'lol']
# ['My', 'boss', 'just', 'called', 'me', 'over', 'to', 'his', 'desk', 'to', 'take', 'my', 'order', 'for', 'Chipotle', 'today']
# ['sales', 'mgr', 'needed', 'for', 'Cleveland', 'or', 'Columbus', 'yrs', 'of', 'overall', 'exp', 'wat', 'least', 'yrs', 'of', 'sales', 'mgmt', 'exp', 'email']
# ['Psst', 'Were', 'doing', 'another', 'FEE', 'FREE', 'Friday', 'tomorrow', 'for', 'Sundays', 'Wrex', 'the', 'Halls', 'Buy', 'online', 'One', 'day', 'only']
# ['your', 'welcome']
# ['You', 'never', 'lose', 'by', 'loving', 'You', 'always', 'lose', 'by', 'holding', 'back', 'Barbara', 'De', 'Angelis']
# ['I', 'swear', 'everyone', 'around', 'here', 'is', 'lookin', 'for', 'a', 'job']
# ['Know', 'of', 'any', 'good', 'Mobile', 'Marketing', 'conferences', 'coming', 'up', 'Let', 'me', 'know']
# ['I', 'just', 'bought', 'shoes', 'For', 'Fred', 'Segal', 'sale', 'Go']
# ['Looking', 'forward', 'to', 'more', 'inspiration', 'at', 'ISASTC', 'Enjoyed', 'your', 'presentation', 'in', 'Austin', 'visiting', 'with', 'you', 'and', 'at', 'dinner']
# ['just', 'saw', 'the', 'ima', 'gonna', 'lick', 'you', 'convo', 'with', 'marv', 'albert', 'and', 'his', 'kinky', 'ways', 'Think', 'he', 'also', 'wore', 'panties', 'Thx', 'for', 'including', 'me', 'Haha']
# ['Today', 'is', 'my', 'th', 'BIRTHDAY', 'and', 'I', 'love', 'you', 'so', 'so', 'so', 'much', 'Will', 'you', 'please', 'follow', 'me', 'back']
# ['where', 'are', 'you', 'from']
# ['Having', 'a', 'cozy', 'divey', 'evening', 'with', 'BBQ', 'at', 'Jamies', 'then', 'Back', 'Door', 'Lounge']
# ['Uh', 'ohthe', 'whooping', 'cough', 'is', 'back']
# ['Its', 'to', 'early', 'to', 'fall', 'asleep']
# ['haha', 'Ill', 'be', 'like', 'can', 'I', 'talk', 'to', 'Bethany', 'please', 'Lol']
# ['DS', 'is', 'covering', 'the', 'InfoShop', 'event', 'with', 'Thomas', 'Sedlacek', 'author', 'of', 'Economics', 'of', 'Good', 'and', 'Evil', 'right', 'now', 'bitlyoROdKR']
# ['Rolling', 'Bob', 'Band', 'rocks', 'Oskar', 'BLues', 'in', 'Lyons', 'tonight', 'for', 'Van', 'MorrisonBand', 'Tribute', 'Night', 'Starts', 'well', 'prob', 'play', 'our', 'songs', 'abt']
# ['I', 'love', 'how', 'when', 'was', 'first', 'drafted', 'they', 'were', 'like', 'hes', 'undersized', 'and', 'wont', 'make', 'it', 'in', 'the', 'league', 'and', 'now', 'hes', 'backing', 'down', 'Cs']
# ['RT', 'thanks', 'for', 'the', 'headsup', 'Conference', 'is', 'NOT', 'today', 'sorry', 'for', 'any', 'misinformation', 'cuse', 'is', 'April', 'th']
# ['Thanks', 'for', 'the', 'RT', 'Welcome', 'to', 'new', 'local', 'followers']
# ['they', 'are', 'trying', 'to', 'holler', 'at', 'us']
# ['Chicken', 'Fantastic', 'with', 'Waffle', 'Fries', 'here']
# ['Madness', 'is', 'upon', 'us']
# ['AwwwHahaspellConfidence', 'RT', 'Im', 'the', 'girl', 'your', 'ex', 'girlfriend', 'will', 'hate', 'your', 'mom', 'will', 'love', 'and', 'that', 'you', 'will', 'never', 'forget']
# ['i', 'followed', 'i', 'followed']
# ['were', 'so', 'excited', 'to', 'have', 'both', 'of', 'you']
# ['i', 'cant', 'hatejust', 'support']
# ['Listening', 'to', 'Hammy', 'on', 'from', 'Dallas']
# ['Painting', 'murals', 'late', 'each', 'night', 'is', 'making', 'it', 'super', 'hard', 'to', 'wake', 'up', 'for', 'work', 'in', 'the', 'morning']
# ['Rich', 'people', 'seek', 'cheap', 'deals']
# ['Week', 'I', 'love', 'movies', 'am', 'THRILLED', 'that', 'Billy', 'Crystal', 'will', 'be', 'returning', 'as', 'Host', 'this', 'Sunday']
# ['Theres', 'a', 'THICK', 'LINE', 'between', 'me', 'and', 'other', 'girls', 'Didnt', 'say', 'difference']
# ['Its', 'only', 'a', 'hoarding', 'problem', 'if', 'you', 'never', 'get', 'around', 'to', 'actually', 'getting', 'rid', 'of', 'them', 'they', 'block', 'your', 'hallway', 'forever']
# ['wow', 'cute', 'grammar', 'britt', 'meant', 'to', 'say', 'D', 'as', 'a']
# ['i', 'love', 'the', 'color', 'of', 'this', 'cake']
# ['dang', 'ive', 'been', 'meaning', 'to', 'see', 'that', 'for', 'awhile', 'now']
# ['Hey', 'lets', 'write', 'a', 'song']
# ['now', 'that', 'youve', 'won', 'a', 'grammy', 'what', 'kind', 'of', 'nail', 'polish', 'line', 'will', 'you', 'release', 'So', 'happy', 'for', 'guys', 'way', 'to', 'rep', 'wisco']
# ['College', 'baseball', 'is', 'so', 'fun', 'to', 'watch']
# ['RT', 'Black', 'Up', 'By', 'Shabazz', 'Palaces', 'is', 'everything']
# ['Be', 'Happy', 'Be', 'Healthy', 'Be', 'Beautiful']
# ['An', 'Idea', 'from', 'Robert', 'Allen', 'There', 'are', 'kinds', 'of', 'people', 'blamers', 'learners', 'To', 'be', 'in', 'the', 'more', 'joyful', 'group', 'we', 'can', 'be', 'learners', 'together']
# ['Exhibit', 'Team', 'meeting', 'at', 'my', 'house', 'So', 'exciting', 'to', 'think', 'about', 'the', 'possibilities', 'in', 'store', 'for']

# %% [markdown]
# ## Fonctions de Construction du Modèle

# %%
from collections import defaultdict

def count_n_grams(data: List[List[str]], n: int) -> dict:
    """
    Compte tous les n-grammes dans les données fournies.
    
    Paramètres :
        data (list[list[str]]) : Liste de listes de mots.
        n (int) : nombre de mots dans une séquence (n-gramme).
    
    Retourne :
        n_grams (dict) : Un dictionnaire qui mappe un tuple de n mots à sa fréquence.
    """
    n_grams = defaultdict(int)

    for sentence in data:
        sentence = ['<s>']*(n-1) + sentence + ['</s>']
        for i in range(len(sentence) - n + 1):
            n_grams[tuple(sentence[i:i+n])] += 1
    
    return n_grams

# %%
def train_ngram_model(data: List[List[str]], ngram_size: int, k: float) -> dict:
    """
    Entraîne un modèle de n-gramme avec lissage add-k à partir des données fournies.
    """
    n_grams = count_n_grams(data, ngram_size)
    vocab_size = len(set(word for sentence in data for word in sentence))

    # Calcul des probabilités avec lissage add-k et normalisation
    ngram_probs = {}
    for ngram, count in n_grams.items():
        context = " ".join(ngram[:-1])
        word = ngram[-1]
        context_count = sum(value for key, value in n_grams.items() if key[:-1] == ngram[:-1])
        prob = (count + k) / (context_count + k * vocab_size)
        
        if context in ngram_probs:
            ngram_probs[context][word] = prob 
        else:
            ngram_probs[context] = {word: prob }

    return ngram_probs


ngram_size = 2
k = 0.01
ngram_model = train_ngram_model(phrases_tokenisees, ngram_size, k)

# %% [markdown]
# ## Fonctions d'Évaluation du Modèle

# %%
import math

def predict_ngram(sentence: str, ngram_model: dict, ngram_size: int) -> float:
    """
    Calcule la probabilité d'une phrase donnée en utilisant un modèle de n-gramme.

    Paramètres :
        sentence (str) : La phrase dont on veut calculer la probabilité.
        ngram_model (dict) : Le modèle de n-gramme entraîné, contenant les probabilités des n-grammes.
        ngram_size (int) : La taille des n-grammes à utiliser dans le modèle.

    Retourne :
        float : La probabilité logarithmique de la phrase selon le modèle de n-gramme.
    """
    # Normalisation de la phrase
    tokens = sentence.lower().split()
    n = len(tokens)

    total_log_prob = 0.0
    for i in range(ngram_size - 1, n):
        context = " ".join(tokens[i - ngram_size + 1:i])
        word = tokens[i]
        if context in ngram_model and word in ngram_model[context]:
            total_log_prob += math.log(ngram_model[context][word])
        else:
            pass

    return total_log_prob

# %%
def calculate_perplexity(test_data: List[List[str]], ngram_model: dict, ngram_size: int) -> float:
    """
    Calcule la perplexité d'un modèle de langue n-gramme sur un ensemble de données de test.

    Paramètres :
        test_data (List[List[str]]) : Les données de test sous forme de listes de listes de mots.
        ngram_model (dict) : Le modèle de langue n-gramme entraîné.
        ngram_size (int) : La taille des n-grammes utilisée dans le modèle.

    Retourne :
        float : La perplexité calculée.
    """
    total_log_prob = 0.0
    total_words = 0

    for sentence in test_data:
        sentence = ['<s>']*(ngram_size-1) + sentence + ['</s>']
        for i in range(ngram_size - 1, len(sentence)):
            context = " ".join(sentence[i - ngram_size + 1:i])
            word = sentence[i]
            if context in ngram_model and word in ngram_model[context]:
                total_log_prob += math.log(ngram_model[context][word])
            else:
                pass
                
            total_words += 1
    
    # Calcul de la perplexité
    perplexity = math.exp(-total_log_prob / total_words)
    return perplexity

# %%
# Calcul de la perplexité sur les données de test
test_file_path = "C:\\Users\\user\\Downloads\\23032024125908292688468987\\PA_files\\big_data_chunk_3.txt"  
with open(test_file_path, 'r', encoding='utf-8') as file:
    test_data = process_data(file.read())[1]  

perplexity = calculate_perplexity(test_data, ngram_model, ngram_size)
print(f"Perplexity on test data: {perplexity:.4f}")
# Out:
# Perplexity on test data: 8.9206

# %% [markdown]
# # Génération de Texte à l'Aide d'un Modèle de Langue N-gramme

# %% [markdown]
# # generateText()

# %% [markdown]
# Cette fonction génère du texte en utilisant un modèle de langue n-gramme préalablement entraîné. Elle prend en entrée le modèle de n-gramme, la taille des n-grammes utilisée dans le modèle et le nombre maximal de mots à générer (par défaut 100). La génération de texte se fait en sélectionnant itérativement le prochain mot en fonction du contexte actuel et des probabilités du modèle. La fonction s'arrête lorsque le jeton de fin de phrase "</s>" est généré ou lorsque le nombre maximal de mots est atteint.

# %%
import numpy as np

def generateText(ngram_model: dict, ngram_size: int, max_words: int = 100) -> str:
    """
    Génère un texte en utilisant un modèle de n-gramme.

    Paramètres :
        ngram_model (dict) : Le modèle de n-gramme entraîné.
        ngram_size (int) : La taille des n-grammes utilisée dans le modèle.
        max_words (int) : Le nombre maximum de mots à générer (par défaut 100).

    Retourne :
        str : Le texte généré.
    """
    generated_text = []
    current_context = ['<s>'] * (ngram_size - 1)

    # Boucle jusqu'à ce que le jeton de fin de phrase </s> soit généré ou que le nombre maximum de mots soit atteint
    while len(generated_text) < max_words:
        context = " ".join(current_context)
        
        # Sélection du prochain mot basé sur le contexte actuel et les probabilités du modèle
        next_word_probs = ngram_model.get(context, {})
        if not next_word_probs:
            break  # Arrêter si le contexte actuel n'a pas de mots suivants dans le modèle

        next_words = list(next_word_probs.keys())
        probabilities = list(next_word_probs.values())
        
        # Normalisation des probabilités pour s'assurer qu'elles s'ajoutent à 1
        total_probability = sum(probabilities)
        normalized_probabilities = [prob / total_probability for prob in probabilities]
        
        # Sélection du mot suivant en utilisant les probabilités normalisées
        next_word = np.random.choice(next_words, p=normalized_probabilities)
        
        # Ajout du mot généré à la liste du texte généré
        generated_text.append(next_word)
        
        # Mise à jour du contexte pour inclure le nouveau mot généré
        current_context.pop(0)
        current_context.append(next_word)
        
        # Arrêter la génération si le jeton de fin de phrase </s> est généré
        if next_word == '</s>':
            break

    return ' '.join(generated_text)

# %% [markdown]
# # Texte Généré

# %%
generated_text = generateText(ngram_model, ngram_size=2, max_words=100)
print(generated_text)
# Out:
# Time offer Get here in years </s>
